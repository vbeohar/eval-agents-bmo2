# %% [markdown]
# # Data & Tools Exploration - BMO2
#
# This notebook walks you through the foundational layer of the AML investigation setup:
# - What the database looks like and how it's built
# - How to explore transactions and accounts manually
# - What the `ReadOnlySqlDatabase` tool is and why it exists
# - How an agent would "see" the database through that tool

# %%
import os
import sqlite3
from pathlib import Path

import pandas as pd
from aieng.agent_evals.aml_investigation.data import download_dataset_file, normalize_transactions_data
from aieng.agent_evals.tools.sql_database import ReadOnlySqlDatabase
from dotenv import load_dotenv

import os
from pathlib import Path

project_root = Path("/home/coder/eval-agents-bmo2/eval-agents-bmo2")

if Path.cwd() != project_root:
    os.chdir(project_root)

# print(f"Working directory: {Path.cwd()}")

# # Setting the notebook directory to the project's root folder
# if Path("").absolute().name == "eval-agents":
#     print(f"Notebook path is already the root path: {Path('').absolute()}")
# else:
#     os.chdir(Path("").absolute().parent.parent)
#     print(f"The notebook path has been set to: {Path('').absolute()}")

load_dotenv(verbose=True)
# Out:
# True

# %% [markdown]
# ## 1. Exploring the dataset
#
# We will be using the [IBM Transactions for Anti Money Laundering (AML)](https://www.kaggle.com/datasets/ealtman2019/ibm-transactions-for-anti-money-laundering-aml) dataset, which is available on Kaggle. It contains synthetic transaction data designed to mimic real-world financial transactions, including both legitimate and potentially fraudulent activities. The dataset includes various features such as transaction amount, type, origin and destination accounts, timestamps, and a label indicating whether the transaction is fraudulent or not.

# %% [markdown]
# ### 1.1 Downloading the dataset
#
# There are 6 datasets available, divided into two groups of three sets. The groups are based on the ratio of illicit transactions in the data:
# - Group **HI** contains relatively higher illicit transaction ratios (i.e. more laundering activity)
# - Group **LI** contains relatively lower illicit transaction ratios (i.e. less laundering activity)
#
# Each group has three sets of data based on the total number of transactions/accounts: "Small", "Medium", and "Large".
#
# You can download any of the six datasets using the `download_dataset_file` function. However, **note that the code tries to load all the data into memory at once, so the "Medium" and "Large" datasets may cause memory issues on some machines**. For this reason, we recommend starting with the "Small" dataset.
#
# Each dataset has 3 files that you can download separately:
# - `<HI/LI>_<Small/Medium/Large>_Trans.csv`: contains transaction data, with each row representing a single transaction.
# - `<HI/LI>_<Small/Medium/Large>_accounts.csv`: contains account data, with each row representing a single account.
# - `<HI/LI>_<Small/Medium/Large>_Patterns.txt`: contains ground-truth laundering patterns, which are groups of transactions that are known to be part of the same laundering scheme. Each pattern includes a list of transaction IDs that are involved in that pattern.

# %% [markdown]
# #### 1.1.1. The transactions

# %%
path_to_transactions_csv = download_dataset_file(illicit_ratio="HI", transactions_size="Small", filename="Trans.csv")
print(f"Path to transactions.csv: {path_to_transactions_csv}")
# Out:
# Path to transactions.csv: /home/coder/.cache/kagglehub/datasets/ealtman2019/ibm-transactions-for-anti-money-laundering-aml/versions/8/HI-Small_Trans.csv

# %%
transactions_df = pd.read_csv(path_to_transactions_csv)
transactions_df.head(10)
# Out:
#           Timestamp  From Bank    Account  To Bank  Account.1  \
# 0  2022/09/01 00:20         10  8000EBD30       10  8000EBD30
# 1  2022/09/01 00:20       3208  8000F4580        1  8000F5340
# 2  2022/09/01 00:00       3209  8000F4670     3209  8000F4670
# 3  2022/09/01 00:02         12  8000F5030       12  8000F5030
# 4  2022/09/01 00:06         10  8000F5200       10  8000F5200
# 5  2022/09/01 00:03          1  8000F5AD0        1  8000F5AD0
# 6  2022/09/01 00:08          1  8000EBAC0        1  8000EBAC0
# 7  2022/09/01 00:16          1  8000EC1E0        1  8000EC1E0
# 8  2022/09/01 00:26         12  8000EC280     2439  8017BF800
# 9  2022/09/01 00:21          1  8000EDEC0   211050  80AEF5310
#
#    Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 0          3697.34          US Dollar      3697.34        US Dollar
# 1             0.01          US Dollar         0.01        US Dollar
# 2         14675.57          US Dollar     14675.57        US Dollar
# 3          2806.97          US Dollar      2806.97        US Dollar
# 4         36682.97          US Dollar     36682.97        US Dollar
# 5          6162.44          US Dollar      6162.44        US Dollar
# 6            14.26          US Dollar        14.26        US Dollar
# 7            11.86          US Dollar        11.86        US Dollar
# 8             7.66          US Dollar         7.66        US Dollar
# 9           383.71          US Dollar       383.71        US Dollar
#
#   Payment Format  Is Laundering
# 0   Reinvestment              0
# 1         Cheque              0
# 2   Reinvestment              0
# 3   Reinvestment              0
# 4   Reinvestment              0
# 5   Reinvestment              0
# 6   Reinvestment              0
# 7   Reinvestment              0
# 8    Credit Card              0
# 9    Credit Card              0

# %%
len(transactions_df)
# Out:
# 5078345

# %%
# Are there duplicates?
print(f"Number of duplicate transactions: {transactions_df.duplicated().sum()}")
# Out:
# Number of duplicate transactions: 9

# %% [markdown]
# Notice that the transactions dataset needs some cleaning. For example:
# - There are duplicate transactions that should be removed before analysis.
# - There are two columns that have the same name "Account". Pandas automatically renamed the second one to "Account.1", but we should rename them to something more descriptive.
#
# We use the `normalize_transactions_data` function to perform these cleaning steps and make the transactions data easier to work with.

# %%
transactions_df = normalize_transactions_data(transactions_df)
transactions_df.head(10)
# Out:
#              timestamp  from_bank from_account  to_bank to_account  \
# 0  2022-09-01T00:00:00       3209    8000F4670     3209  8000F4670
# 1  2022-09-01T00:00:00       1420    8005DFEB0     1420  8005DFEB0
# 2  2022-09-01T00:00:00         10    8000F6850       10  8000F6850
# 3  2022-09-01T00:00:00         12    8001167D0       12  8001167D0
# 4  2022-09-01T00:00:00          1    8001364A0        1  8001364A0
# 5  2022-09-01T00:00:00          1    800139380        1  800139380
# 6  2022-09-01T00:00:00        220    800132390      220  800132390
# 7  2022-09-01T00:00:00          1    8001495E0        1  8001495E0
# 8  2022-09-01T00:00:00       3292    8001541B0     3292  8001541B0
# 9  2022-09-01T00:00:00       3211    8001583E0     3211  8001583E0
#
#    amount_received receiving_currency  amount_paid payment_currency  \
# 0         14675.57          US Dollar     14675.57        US Dollar
# 1           897.37          US Dollar       897.37        US Dollar
# 2         99986.94          US Dollar     99986.94        US Dollar
# 3            16.08          US Dollar        16.08        US Dollar
# 4            10.30          US Dollar        10.30        US Dollar
# 5            18.51          US Dollar        18.51        US Dollar
# 6            19.23          US Dollar        19.23        US Dollar
# 7         19227.79          US Dollar     19227.79        US Dollar
# 8          3776.79          US Dollar      3776.79        US Dollar
# 9           400.56          US Dollar       400.56        US Dollar
#
#   payment_format  is_laundering    transaction_id
# 0   Reinvestment              0  7abd6ee7ce337fa6
# 1   Reinvestment              0  b20fff430d669279
# 2   Reinvestment              0  cadfa0752d04b411
# 3   Reinvestment              0  52686389365c1dbb
# 4   Reinvestment              0  bb04ab773bf948f4
# 5   Reinvestment              0  9cab46e294b23f33
# 6   Reinvestment              0  56a6d97492dd7e9e
# 7   Reinvestment              0  09d9ed451d4ed49a
# 8   Reinvestment              0  b81f975bae134449
# 9   Reinvestment              0  562f94dd547e0314

# %% [markdown]
# #### 1.1.2. The accounts

# %%
path_to_accounts_csv = download_dataset_file(illicit_ratio="HI", transactions_size="Small", filename="accounts.csv")
print(f"Path to accounts.csv: {path_to_accounts_csv}")
# Out:
# Path to accounts.csv: /home/coder/.cache/kagglehub/datasets/ealtman2019/ibm-transactions-for-anti-money-laundering-aml/versions/8/HI-Small_accounts.csv

# %%
accounts_df = pd.read_csv(path_to_accounts_csv)
accounts_df.head(10)
# Out:
#                      Bank Name  Bank ID Account Number  Entity ID  \
# 0          Portugal Bank #4507   331579      80B779D80  80062E240
# 1              Canada Bank #27      210      809D86900  800C998A0
# 2                  UK Bank #33    21884      80812BE00  800C47F50
# 3           Germany Bank #4815    32742      81047F300  80096F0B0
# 4  National Bank of Harrisburg   127390      80BD8CF00  800FB8760
# 5              Spain Bank #439   224555      80F269580  80064EB20
# 6        Savings Bank of Omaha    32013      80E6E8680  800CCEDE0
# 7              Brazil Bank #39   335355      80CDEFD80  800D88F10
# 8              Mexico Bank #16     1132      80B723600  800D3F760
# 9              Russia Bank #39   217824      806B17000  800B44480
#
#                   Entity Name
# 0  Sole Proprietorship #50438
# 1          Corporation #33520
# 2          Partnership #35397
# 3          Corporation #48813
# 4            Corporation #889
# 5  Sole Proprietorship #42987
# 6  Sole Proprietorship #20855
# 7          Partnership #36822
# 8          Partnership #36511
# 9          Partnership #33830

# %% [markdown]
# Similar to the transactions dataset, we can rename the columns in the accounts dataset to make them easier to work with.

# %%
accounts_df.rename(
    columns={
        "Bank Name": "bank_name",
        "Bank ID": "bank_id",
        "Account Number": "account_number",
        "Entity ID": "entity_id",
        "Entity Name": "entity_name",
    },
    inplace=True,
)
accounts_df.head(10)
# Out:
#                      bank_name  bank_id account_number  entity_id  \
# 0          Portugal Bank #4507   331579      80B779D80  80062E240
# 1              Canada Bank #27      210      809D86900  800C998A0
# 2                  UK Bank #33    21884      80812BE00  800C47F50
# 3           Germany Bank #4815    32742      81047F300  80096F0B0
# 4  National Bank of Harrisburg   127390      80BD8CF00  800FB8760
# 5              Spain Bank #439   224555      80F269580  80064EB20
# 6        Savings Bank of Omaha    32013      80E6E8680  800CCEDE0
# 7              Brazil Bank #39   335355      80CDEFD80  800D88F10
# 8              Mexico Bank #16     1132      80B723600  800D3F760
# 9              Russia Bank #39   217824      806B17000  800B44480
#
#                   entity_name
# 0  Sole Proprietorship #50438
# 1          Corporation #33520
# 2          Partnership #35397
# 3          Corporation #48813
# 4            Corporation #889
# 5  Sole Proprietorship #42987
# 6  Sole Proprietorship #20855
# 7          Partnership #36822
# 8          Partnership #36511
# 9          Partnership #33830

# %% [markdown]
# #### 1.1.3. The patterns

# %%
path_to_patterns_txt = download_dataset_file(illicit_ratio="HI", transactions_size="Small", filename="Patterns.txt")
print(f"Path to patterns.txt: {path_to_patterns_txt}")
# Out:
# Path to patterns.txt: /home/coder/.cache/kagglehub/datasets/ealtman2019/ibm-transactions-for-anti-money-laundering-aml/versions/8/HI-Small_Patterns.txt

# %% [markdown]
# Laundering patterns start with `BEGIN LAUNDERING ATTEMPT` and end with `END LAUNDERING ATTEMPT`. Each pattern includes a list of transactions that are involved in that pattern.

# %%
# Print the first laundering pattern
begin_prefix = "BEGIN LAUNDERING ATTEMPT - "
end_prefix = "END LAUNDERING ATTEMPT"
with open(path_to_patterns_txt, "r") as f:
    for line in f:
        if line.startswith(begin_prefix):
            print(f"\n{line.strip()}")
        elif line.startswith(end_prefix):
            print(f"{line.strip()}")
            break
        else:
            print(line.strip())
# Out:
# BEGIN LAUNDERING ATTEMPT - FAN-OUT:  Max 16-degree Fan-Out
# 2022/09/01 00:06,021174,800737690,012,80011F990,2848.96,Euro,2848.96,Euro,ACH,1
# 2022/09/01 04:33,021174,800737690,020,80020C5B0,8630.40,Euro,8630.40,Euro,ACH,1
# 2022/09/01 09:14,021174,800737690,020,80006A5E0,35642.49,Yuan,35642.49,Yuan,ACH,1
# 2022/09/01 09:56,021174,800737690,00220,8007A5B70,5738987.96,US Dollar,5738987.96,US Dollar,ACH,1
# 2022/09/01 11:28,021174,800737690,001244,80093C0D0,7254.53,US Dollar,7254.53,US Dollar,ACH,1
# 2022/09/01 13:13,021174,800737690,00513,80078E200,6990.87,US Dollar,6990.87,US Dollar,ACH,1
# 2022/09/01 14:11,021174,800737690,020,80066B990,12536.92,Euro,12536.92,Euro,ACH,1
# 2022/09/02 15:40,021174,800737690,00410,8002CC310,3511.82,Euro,3511.82,Euro,ACH,1
# 2022/09/02 21:23,021174,800737690,01292,8004030A0,16135.09,US Dollar,16135.09,US Dollar,ACH,1
# 2022/09/02 23:10,021174,800737690,01601,800578800,12183.28,US Dollar,12183.28,US Dollar,ACH,1
# 2022/09/03 09:29,021174,800737690,001,800AAF0B0,15197.45,US Dollar,15197.45,US Dollar,ACH,1
# 2022/09/03 14:22,021174,800737690,01420,8006FB970,4717.76,US Dollar,4717.76,US Dollar,ACH,1
# 2022/09/04 07:35,021174,800737690,010,800449990,19332.59,US Dollar,19332.59,US Dollar,ACH,1
# 2022/09/04 09:10,021174,800737690,011852,800AEBA90,300.93,Euro,300.93,Euro,ACH,1
# 2022/09/04 12:03,021174,800737690,010,800692550,2724.99,US Dollar,2724.99,US Dollar,ACH,1
# 2022/09/04 15:48,021174,800737690,011056,8007486D0,15224.53,Euro,15224.53,Euro,ACH,1
# END LAUNDERING ATTEMPT - FAN-OUT

# %% [markdown]
# ## 2. Build the Database
#
# With the datasets downloaded and cleaned, we can build a SQLite database that contains the transactions and accounts data. This will allow us to query the data using SQL, which is a common way for agents to interact with databases.

# %%
DB_PATH = Path("implementations/aml_investigation/data/aml_transactions.db")
DDL_PATH = Path("implementations/aml_investigation/data/schema.ddl")

print(f"Database exists: {DB_PATH.exists()}")
print(f"DDL file exists: {DDL_PATH.exists()}")
# Out:
# Database exists: True
# DDL file exists: True

# %%
# Run this cell only if the database doesn't exist yet.
# It will build the SQLite DB. It may take some time to run.

if not DB_PATH.exists():
    with sqlite3.connect(DB_PATH) as conn:
        conn.execute("PRAGMA foreign_keys = ON;")

        if not DDL_PATH.exists():
            raise FileNotFoundError(f"DDL file not found at {DDL_PATH}")

        with open(DDL_PATH, "r") as file:
            conn.executescript(file.read())
        conn.commit()

        # Add new columns to the transactions DataFrame: date, day_of_week, time_of_day
        transactions_df["date"] = pd.to_datetime(transactions_df["timestamp"]).dt.date
        transactions_df["day_of_week"] = pd.to_datetime(transactions_df["timestamp"]).dt.day_name()
        transactions_df["time_of_day"] = pd.to_datetime(transactions_df["timestamp"]).dt.time

        # Set Transaction ID as index
        transactions_df.set_index("transaction_id", drop=True, inplace=True)

        # NOTE: We drop the "is_laundering" column since that's the label the
        # agent is trying to predict, and it wouldn't be present in a real
        # investigation scenario.
        transactions_df.drop(columns=["is_laundering"], inplace=True)

        accounts_df.to_sql("accounts", conn, if_exists="append", index=False)
        transactions_df.to_sql("transactions", conn, if_exists="append")
else:
    print("Database already exists — skipping creation.")
# Out:
# Database already exists — skipping creation.

# %%
# with sqlite3.connect(DB_PATH) as conn:
#     conn.execute("PRAGMA foreign_keys = ON;")

#     if not DDL_PATH.exists():
#         raise FileNotFoundError(f"DDL file not found at {DDL_PATH}")

#     with open(DDL_PATH, "r") as file:
#         conn.executescript(file.read())
#     conn.commit()

#     # Add new columns to the transactions DataFrame: date, day_of_week, time_of_day
#     transactions_df["date"] = pd.to_datetime(transactions_df["timestamp"]).dt.date
#     transactions_df["day_of_week"] = pd.to_datetime(transactions_df["timestamp"]).dt.day_name()
#     transactions_df["time_of_day"] = pd.to_datetime(transactions_df["timestamp"]).dt.time

#     # Set Transaction ID as index
#     transactions_df.set_index("transaction_id", drop=True, inplace=True)

#     # NOTE: We drop the "is_laundering" column since that's the label the
#     # agent is trying to predict, and it wouldn't be present in a real
#     # investigation scenario.
#     transactions_df.drop(columns=["is_laundering"], inplace=True)

#     # accounts_df.to_sql("accounts", conn, if_exists="append", index=False)
#     transactions_df.to_sql("transactions", conn, if_exists="append")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import sqlite3
import pandas as pd
import time


def build_database_debug(db_path, ddl_path, accounts_df, transactions_df):
    start_time = time.time()

    try:
        if db_path.exists():
            print("Database already exists — skipping creation.")
            return

        print("STEP 1: Checking DDL...")
        if not ddl_path.exists():
            raise FileNotFoundError(f"DDL file not found at {ddl_path}")

        print("STEP 2: Copying transactions_df...")
        tx_df = transactions_df.copy()

        print("STEP 3: Parsing timestamps...")
        ts = pd.to_datetime(tx_df["timestamp"], errors="coerce")

        print("STEP 4: Creating derived columns...")
        tx_df["date"] = ts.dt.strftime("%Y-%m-%d")
        tx_df["day_of_week"] = ts.dt.day_name()
        tx_df["time_of_day"] = ts.dt.strftime("%H:%M:%S")

        print("STEP 5: Dropping label column...")
        tx_df = tx_df.drop(columns=["is_laundering"], errors="ignore")

        print("STEP 6: Setting index...")
        tx_df = tx_df.set_index("transaction_id", drop=True)

        print("STEP 7: DataFrame info:")
        print(tx_df.info())
        print(tx_df.head(3))

        print("STEP 8: Opening DB connection...")
        with sqlite3.connect(db_path) as conn:
            conn.execute("PRAGMA foreign_keys = ON;")

            print("STEP 9: Executing DDL...")
            with open(ddl_path, "r", encoding="utf-8") as file:
                conn.executescript(file.read())

            print("STEP 10: Writing accounts table...")
            try:
                accounts_df.to_sql("accounts", conn, if_exists="append", index=False)
                print("✅ accounts inserted")
            except Exception as e:
                print("❌ ERROR writing accounts:", type(e).__name__, e)
                raise

            print("STEP 11: Writing transactions in batches...")

            chunk_size = 1000
            try:
                tx_df = tx_df.reset_index()  # avoid index overhead

                for i in range(0, len(tx_df), chunk_size):
                    print(f"→ Inserting batch {i} to {i + chunk_size}")

                    chunk = tx_df.iloc[i:i + chunk_size]

                    chunk.to_sql(
                        "transactions",
                        conn,
                        if_exists="append",
                        index=False
                    )

                print("✅ transactions inserted")

            except Exception as e:
                print("❌ ERROR writing transactions:", type(e).__name__, e)
                raise

            print("STEP 12: Commit...")
            conn.commit()

        print(f"✅ Database created successfully in {time.time() - start_time:.2f}s")

    except Exception as e:
        print("\n🔥 FATAL ERROR:", type(e).__name__, e)
        raise

# %%
build_database_debug(
    db_path=DB_PATH,
    ddl_path=DDL_PATH,
    accounts_df=accounts_df,
    transactions_df=transactions_df,
)
# Out:
# STEP 1: Checking DDL...
# STEP 2: Copying transactions_df...
# STEP 3: Parsing timestamps...
# STEP 4: Creating derived columns...
# STEP 5: Dropping label column...
# STEP 6: Setting index...
# STEP 7: DataFrame info:
# <class 'pandas.DataFrame'>
# Index: 5078336 entries, 7abd6ee7ce337fa6 to 9a5e6db071ecd862
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   timestamp           str
#  1   from_bank           int64
#  2   from_account        str
#  3   to_bank             int64
#  4   to_account          str
#  5   amount_received     float64
#  6   receiving_currency  str
#  7   amount_paid         float64
#  8   payment_currency    str
#  9   payment_format      str
#  10  date                str
#  11  day_of_week         str
#  12  time_of_day         str
# dtypes: float64(2), int64(2), str(9)
# memory usage: 1.0 GB
# None
#                             timestamp  from_bank from_account  to_bank  \
# transaction_id
# 7abd6ee7ce337fa6  2022-09-01T00:00:00       3209    8000F4670     3209
# b20fff430d669279  2022-09-01T00:00:00       1420    8005DFEB0     1420
# cadfa0752d04b411  2022-09-01T00:00:00         10    8000F6850       10
#
#                  to_account  amount_received receiving_currency  amount_paid  \
# transaction_id
# 7abd6ee7ce337fa6  8000F4670         14675.57          US Dollar     14675.57
# b20fff430d669279  8005DFEB0           897.37          US Dollar       897.37
# cadfa0752d04b411  8000F6850         99986.94          US Dollar     99986.94
#
#                  payment_currency payment_format        date day_of_week  \
# transaction_id
# 7abd6ee7ce337fa6        US Dollar   Reinvestment  2022-09-01    Thursday
# b20fff430d669279        US Dollar   Reinvestment  2022-09-01    Thursday
# cadfa0752d04b411        US Dollar   Reinvestment  2022-09-01    Thursday
#
#                  time_of_day
# transaction_id
# 7abd6ee7ce337fa6    00:00:00
# b20fff430d669279    00:00:00
# cadfa0752d04b411    00:00:00
# STEP 8: Opening DB connection...
# STEP 9: Executing DDL...
# STEP 10: Writing accounts table...
# ✅ accounts inserted
# STEP 11: Writing transactions in batches...
# → Inserting batch 0 to 1000
# → Inserting batch 1000 to 2000
# → Inserting batch 2000 to 3000
# → Inserting batch 3000 to 4000
# → Inserting batch 4000 to 5000
# → Inserting batch 5000 to 6000
# → Inserting batch 6000 to 7000
# → Inserting batch 7000 to 8000
# → Inserting batch 8000 to 9000
# → Inserting batch 9000 to 10000
# → Inserting batch 10000 to 11000
# → Inserting batch 11000 to 12000
# → Inserting batch 12000 to 13000
# → Inserting batch 13000 to 14000
# → Inserting batch 14000 to 15000
# → Inserting batch 15000 to 16000
# → Inserting batch 16000 to 17000
# → Inserting batch 17000 to 18000
# → Inserting batch 18000 to 19000
# → Inserting batch 19000 to 20000
# → Inserting batch 20000 to 21000
# → Inserting batch 21000 to 22000
# → Inserting batch 22000 to 23000
# → Inserting batch 23000 to 24000
# → Inserting batch 24000 to 25000
# → Inserting batch 25000 to 26000
# → Inserting batch 26000 to 27000
# → Inserting batch 27000 to 28000
# → Inserting batch 28000 to 29000
# → Inserting batch 29000 to 30000
# → Inserting batch 30000 to 31000
# → Inserting batch 31000 to 32000
# → Inserting batch 32000 to 33000
# → Inserting batch 33000 to 34000
# → Inserting batch 34000 to 35000
# → Inserting batch 35000 to 36000
# → Inserting batch 36000 to 37000
# → Inserting batch 37000 to 38000
# → Inserting batch 38000 to 39000
# → Inserting batch 39000 to 40000
# → Inserting batch 40000 to 41000
# → Inserting batch 41000 to 42000
# → Inserting batch 42000 to 43000
# → Inserting batch 43000 to 44000
# → Inserting batch 44000 to 45000
# → Inserting batch 45000 to 46000
# → Inserting batch 46000 to 47000
# → Inserting batch 47000 to 48000
# → Inserting batch 48000 to 49000
# → Inserting batch 49000 to 50000
# → Inserting batch 50000 to 51000
# → Inserting batch 51000 to 52000
# → Inserting batch 52000 to 53000
# → Inserting batch 53000 to 54000
# → Inserting batch 54000 to 55000
# → Inserting batch 55000 to 56000
# → Inserting batch 56000 to 57000
# → Inserting batch 57000 to 58000
# → Inserting batch 58000 to 59000
# → Inserting batch 59000 to 60000
# → Inserting batch 60000 to 61000
# → Inserting batch 61000 to 62000
# → Inserting batch 62000 to 63000
# → Inserting batch 63000 to 64000
# → Inserting batch 64000 to 65000
# → Inserting batch 65000 to 66000
# → Inserting batch 66000 to 67000
# → Inserting batch 67000 to 68000
# → Inserting batch 68000 to 69000
# → Inserting batch 69000 to 70000
# → Inserting batch 70000 to 71000
# → Inserting batch 71000 to 72000
# → Inserting batch 72000 to 73000
# → Inserting batch 73000 to 74000
# → Inserting batch 74000 to 75000
# → Inserting batch 75000 to 76000
# → Inserting batch 76000 to 77000
# → Inserting batch 77000 to 78000
# → Inserting batch 78000 to 79000
# → Inserting batch 79000 to 80000
# → Inserting batch 80000 to 81000
# → Inserting batch 81000 to 82000
# → Inserting batch 82000 to 83000
# → Inserting batch 83000 to 84000
# → Inserting batch 84000 to 85000
# → Inserting batch 85000 to 86000
# → Inserting batch 86000 to 87000
# → Inserting batch 87000 to 88000
# → Inserting batch 88000 to 89000
# → Inserting batch 89000 to 90000
# → Inserting batch 90000 to 91000
# → Inserting batch 91000 to 92000
# → Inserting batch 92000 to 93000
# → Inserting batch 93000 to 94000
# → Inserting batch 94000 to 95000
# → Inserting batch 95000 to 96000
# → Inserting batch 96000 to 97000
# → Inserting batch 97000 to 98000
# → Inserting batch 98000 to 99000
# → Inserting batch 99000 to 100000
# → Inserting batch 100000 to 101000
# → Inserting batch 101000 to 102000
# → Inserting batch 102000 to 103000
# → Inserting batch 103000 to 104000
# → Inserting batch 104000 to 105000
# → Inserting batch 105000 to 106000
# → Inserting batch 106000 to 107000
# → Inserting batch 107000 to 108000
# → Inserting batch 108000 to 109000
# → Inserting batch 109000 to 110000
# → Inserting batch 110000 to 111000
# → Inserting batch 111000 to 112000
# → Inserting batch 112000 to 113000
# → Inserting batch 113000 to 114000
# → Inserting batch 114000 to 115000
# → Inserting batch 115000 to 116000
# → Inserting batch 116000 to 117000
# → Inserting batch 117000 to 118000
# → Inserting batch 118000 to 119000
# → Inserting batch 119000 to 120000
# → Inserting batch 120000 to 121000
# → Inserting batch 121000 to 122000
# → Inserting batch 122000 to 123000
# → Inserting batch 123000 to 124000
# → Inserting batch 124000 to 125000
# → Inserting batch 125000 to 126000
# → Inserting batch 126000 to 127000
# → Inserting batch 127000 to 128000
# → Inserting batch 128000 to 129000
# → Inserting batch 129000 to 130000
# → Inserting batch 130000 to 131000
# → Inserting batch 131000 to 132000
# → Inserting batch 132000 to 133000
# → Inserting batch 133000 to 134000
# → Inserting batch 134000 to 135000
# → Inserting batch 135000 to 136000
# → Inserting batch 136000 to 137000
# → Inserting batch 137000 to 138000
# → Inserting batch 138000 to 139000
# → Inserting batch 139000 to 140000
# → Inserting batch 140000 to 141000
# → Inserting batch 141000 to 142000
# → Inserting batch 142000 to 143000
# → Inserting batch 143000 to 144000
# → Inserting batch 144000 to 145000
# → Inserting batch 145000 to 146000
# → Inserting batch 146000 to 147000
# → Inserting batch 147000 to 148000
# → Inserting batch 148000 to 149000
# → Inserting batch 149000 to 150000
# → Inserting batch 150000 to 151000
# → Inserting batch 151000 to 152000
# → Inserting batch 152000 to 153000
# → Inserting batch 153000 to 154000
# → Inserting batch 154000 to 155000
# → Inserting batch 155000 to 156000
# → Inserting batch 156000 to 157000
# → Inserting batch 157000 to 158000
# → Inserting batch 158000 to 159000
# → Inserting batch 159000 to 160000
# → Inserting batch 160000 to 161000
# → Inserting batch 161000 to 162000
# → Inserting batch 162000 to 163000
# → Inserting batch 163000 to 164000
# → Inserting batch 164000 to 165000
# → Inserting batch 165000 to 166000
# → Inserting batch 166000 to 167000
# → Inserting batch 167000 to 168000
# → Inserting batch 168000 to 169000
# → Inserting batch 169000 to 170000
# → Inserting batch 170000 to 171000
# → Inserting batch 171000 to 172000
# → Inserting batch 172000 to 173000
# → Inserting batch 173000 to 174000
# → Inserting batch 174000 to 175000
# → Inserting batch 175000 to 176000
# → Inserting batch 176000 to 177000
# → Inserting batch 177000 to 178000
# → Inserting batch 178000 to 179000
# → Inserting batch 179000 to 180000
# → Inserting batch 180000 to 181000
# → Inserting batch 181000 to 182000
# → Inserting batch 182000 to 183000
# → Inserting batch 183000 to 184000
# → Inserting batch 184000 to 185000
# → Inserting batch 185000 to 186000
# → Inserting batch 186000 to 187000
# → Inserting batch 187000 to 188000
# → Inserting batch 188000 to 189000
# → Inserting batch 189000 to 190000
# → Inserting batch 190000 to 191000
# → Inserting batch 191000 to 192000
# → Inserting batch 192000 to 193000
# → Inserting batch 193000 to 194000
# → Inserting batch 194000 to 195000
# → Inserting batch 195000 to 196000
# → Inserting batch 196000 to 197000
# → Inserting batch 197000 to 198000
# → Inserting batch 198000 to 199000
# → Inserting batch 199000 to 200000
# → Inserting batch 200000 to 201000
# → Inserting batch 201000 to 202000
# → Inserting batch 202000 to 203000
# → Inserting batch 203000 to 204000
# → Inserting batch 204000 to 205000
# → Inserting batch 205000 to 206000
# → Inserting batch 206000 to 207000
# → Inserting batch 207000 to 208000
# → Inserting batch 208000 to 209000
# → Inserting batch 209000 to 210000
# → Inserting batch 210000 to 211000
# → Inserting batch 211000 to 212000
# → Inserting batch 212000 to 213000
# → Inserting batch 213000 to 214000
# → Inserting batch 214000 to 215000
# → Inserting batch 215000 to 216000
# → Inserting batch 216000 to 217000
# → Inserting batch 217000 to 218000
# → Inserting batch 218000 to 219000
# → Inserting batch 219000 to 220000
# → Inserting batch 220000 to 221000
# → Inserting batch 221000 to 222000
# → Inserting batch 222000 to 223000
# → Inserting batch 223000 to 224000
# → Inserting batch 224000 to 225000
# → Inserting batch 225000 to 226000
# → Inserting batch 226000 to 227000
# → Inserting batch 227000 to 228000
# → Inserting batch 228000 to 229000
# → Inserting batch 229000 to 230000
# → Inserting batch 230000 to 231000
# → Inserting batch 231000 to 232000
# → Inserting batch 232000 to 233000
# → Inserting batch 233000 to 234000
# → Inserting batch 234000 to 235000
# → Inserting batch 235000 to 236000
# → Inserting batch 236000 to 237000
# → Inserting batch 237000 to 238000
# → Inserting batch 238000 to 239000
# → Inserting batch 239000 to 240000
# → Inserting batch 240000 to 241000
# → Inserting batch 241000 to 242000
# → Inserting batch 242000 to 243000
# → Inserting batch 243000 to 244000
# → Inserting batch 244000 to 245000
# → Inserting batch 245000 to 246000
# → Inserting batch 246000 to 247000
# → Inserting batch 247000 to 248000
# → Inserting batch 248000 to 249000
# → Inserting batch 249000 to 250000
# → Inserting batch 250000 to 251000
# → Inserting batch 251000 to 252000
# → Inserting batch 252000 to 253000
# → Inserting batch 253000 to 254000
# → Inserting batch 254000 to 255000
# → Inserting batch 255000 to 256000
# → Inserting batch 256000 to 257000
# → Inserting batch 257000 to 258000
# → Inserting batch 258000 to 259000
# → Inserting batch 259000 to 260000
# → Inserting batch 260000 to 261000
# → Inserting batch 261000 to 262000
# → Inserting batch 262000 to 263000
# → Inserting batch 263000 to 264000
# → Inserting batch 264000 to 265000
# → Inserting batch 265000 to 266000
# → Inserting batch 266000 to 267000
# → Inserting batch 267000 to 268000
# → Inserting batch 268000 to 269000
# → Inserting batch 269000 to 270000
# → Inserting batch 270000 to 271000
# → Inserting batch 271000 to 272000
# → Inserting batch 272000 to 273000
# → Inserting batch 273000 to 274000
# → Inserting batch 274000 to 275000
# → Inserting batch 275000 to 276000
# → Inserting batch 276000 to 277000
# → Inserting batch 277000 to 278000
# → Inserting batch 278000 to 279000
# → Inserting batch 279000 to 280000
# → Inserting batch 280000 to 281000
# → Inserting batch 281000 to 282000
# → Inserting batch 282000 to 283000
# → Inserting batch 283000 to 284000
# → Inserting batch 284000 to 285000
# → Inserting batch 285000 to 286000
# → Inserting batch 286000 to 287000
# → Inserting batch 287000 to 288000
# → Inserting batch 288000 to 289000
# → Inserting batch 289000 to 290000
# → Inserting batch 290000 to 291000
# → Inserting batch 291000 to 292000
# → Inserting batch 292000 to 293000
# → Inserting batch 293000 to 294000
# → Inserting batch 294000 to 295000
# → Inserting batch 295000 to 296000
# → Inserting batch 296000 to 297000
# → Inserting batch 297000 to 298000
# → Inserting batch 298000 to 299000
# → Inserting batch 299000 to 300000
# → Inserting batch 300000 to 301000
# → Inserting batch 301000 to 302000
# → Inserting batch 302000 to 303000
# → Inserting batch 303000 to 304000
# → Inserting batch 304000 to 305000
# → Inserting batch 305000 to 306000
# → Inserting batch 306000 to 307000
# → Inserting batch 307000 to 308000
# → Inserting batch 308000 to 309000
# → Inserting batch 309000 to 310000
# → Inserting batch 310000 to 311000
# → Inserting batch 311000 to 312000
# → Inserting batch 312000 to 313000
# → Inserting batch 313000 to 314000
# → Inserting batch 314000 to 315000
# → Inserting batch 315000 to 316000
# → Inserting batch 316000 to 317000
# → Inserting batch 317000 to 318000
# → Inserting batch 318000 to 319000
# → Inserting batch 319000 to 320000
# → Inserting batch 320000 to 321000
# → Inserting batch 321000 to 322000
# → Inserting batch 322000 to 323000
# → Inserting batch 323000 to 324000
# → Inserting batch 324000 to 325000
# → Inserting batch 325000 to 326000
# → Inserting batch 326000 to 327000
# → Inserting batch 327000 to 328000
# → Inserting batch 328000 to 329000
# → Inserting batch 329000 to 330000
# → Inserting batch 330000 to 331000
# → Inserting batch 331000 to 332000
# → Inserting batch 332000 to 333000
# → Inserting batch 333000 to 334000
# → Inserting batch 334000 to 335000
# → Inserting batch 335000 to 336000
# → Inserting batch 336000 to 337000
# → Inserting batch 337000 to 338000
# → Inserting batch 338000 to 339000
# → Inserting batch 339000 to 340000
# → Inserting batch 340000 to 341000
# → Inserting batch 341000 to 342000
# → Inserting batch 342000 to 343000
# → Inserting batch 343000 to 344000
# → Inserting batch 344000 to 345000
# → Inserting batch 345000 to 346000
# → Inserting batch 346000 to 347000
# → Inserting batch 347000 to 348000
# → Inserting batch 348000 to 349000
# → Inserting batch 349000 to 350000
# → Inserting batch 350000 to 351000
# → Inserting batch 351000 to 352000
# → Inserting batch 352000 to 353000
# → Inserting batch 353000 to 354000
# → Inserting batch 354000 to 355000
# → Inserting batch 355000 to 356000
# → Inserting batch 356000 to 357000
# → Inserting batch 357000 to 358000
# → Inserting batch 358000 to 359000
# → Inserting batch 359000 to 360000
# → Inserting batch 360000 to 361000
# → Inserting batch 361000 to 362000
# → Inserting batch 362000 to 363000
# → Inserting batch 363000 to 364000
# → Inserting batch 364000 to 365000
# → Inserting batch 365000 to 366000
# → Inserting batch 366000 to 367000
# → Inserting batch 367000 to 368000
# → Inserting batch 368000 to 369000
# → Inserting batch 369000 to 370000
# → Inserting batch 370000 to 371000
# → Inserting batch 371000 to 372000
# → Inserting batch 372000 to 373000
# → Inserting batch 373000 to 374000
# → Inserting batch 374000 to 375000
# → Inserting batch 375000 to 376000
# → Inserting batch 376000 to 377000
# → Inserting batch 377000 to 378000
# → Inserting batch 378000 to 379000
# → Inserting batch 379000 to 380000
# → Inserting batch 380000 to 381000
# → Inserting batch 381000 to 382000
# → Inserting batch 382000 to 383000
# → Inserting batch 383000 to 384000
# → Inserting batch 384000 to 385000
# → Inserting batch 385000 to 386000
# → Inserting batch 386000 to 387000
# → Inserting batch 387000 to 388000
# → Inserting batch 388000 to 389000
# → Inserting batch 389000 to 390000
# → Inserting batch 390000 to 391000
# → Inserting batch 391000 to 392000
# → Inserting batch 392000 to 393000
# → Inserting batch 393000 to 394000
# → Inserting batch 394000 to 395000
# → Inserting batch 395000 to 396000
# → Inserting batch 396000 to 397000
# → Inserting batch 397000 to 398000
# → Inserting batch 398000 to 399000
# → Inserting batch 399000 to 400000
# → Inserting batch 400000 to 401000
# → Inserting batch 401000 to 402000
# → Inserting batch 402000 to 403000
# → Inserting batch 403000 to 404000
# → Inserting batch 404000 to 405000
# → Inserting batch 405000 to 406000
# → Inserting batch 406000 to 407000
# → Inserting batch 407000 to 408000
# → Inserting batch 408000 to 409000
# → Inserting batch 409000 to 410000
# → Inserting batch 410000 to 411000
# → Inserting batch 411000 to 412000
# → Inserting batch 412000 to 413000
# → Inserting batch 413000 to 414000
# → Inserting batch 414000 to 415000
# → Inserting batch 415000 to 416000
# → Inserting batch 416000 to 417000
# → Inserting batch 417000 to 418000
# → Inserting batch 418000 to 419000
# → Inserting batch 419000 to 420000
# → Inserting batch 420000 to 421000
# → Inserting batch 421000 to 422000
# → Inserting batch 422000 to 423000
# → Inserting batch 423000 to 424000
# → Inserting batch 424000 to 425000
# → Inserting batch 425000 to 426000
# → Inserting batch 426000 to 427000
# → Inserting batch 427000 to 428000
# → Inserting batch 428000 to 429000
# → Inserting batch 429000 to 430000
# → Inserting batch 430000 to 431000
# → Inserting batch 431000 to 432000
# → Inserting batch 432000 to 433000
# → Inserting batch 433000 to 434000
# → Inserting batch 434000 to 435000
# → Inserting batch 435000 to 436000
# → Inserting batch 436000 to 437000
# → Inserting batch 437000 to 438000
# → Inserting batch 438000 to 439000
# → Inserting batch 439000 to 440000
# → Inserting batch 440000 to 441000
# → Inserting batch 441000 to 442000
# → Inserting batch 442000 to 443000
# → Inserting batch 443000 to 444000
# → Inserting batch 444000 to 445000
# → Inserting batch 445000 to 446000
# → Inserting batch 446000 to 447000
# → Inserting batch 447000 to 448000
# → Inserting batch 448000 to 449000
# → Inserting batch 449000 to 450000
# → Inserting batch 450000 to 451000
# → Inserting batch 451000 to 452000
# → Inserting batch 452000 to 453000
# → Inserting batch 453000 to 454000
# → Inserting batch 454000 to 455000
# → Inserting batch 455000 to 456000
# → Inserting batch 456000 to 457000
# → Inserting batch 457000 to 458000
# → Inserting batch 458000 to 459000
# → Inserting batch 459000 to 460000
# → Inserting batch 460000 to 461000
# → Inserting batch 461000 to 462000
# → Inserting batch 462000 to 463000
# → Inserting batch 463000 to 464000
# → Inserting batch 464000 to 465000
# → Inserting batch 465000 to 466000
# → Inserting batch 466000 to 467000
# → Inserting batch 467000 to 468000
# → Inserting batch 468000 to 469000
# → Inserting batch 469000 to 470000
# → Inserting batch 470000 to 471000
# → Inserting batch 471000 to 472000
# → Inserting batch 472000 to 473000
# → Inserting batch 473000 to 474000
# → Inserting batch 474000 to 475000
# → Inserting batch 475000 to 476000
# → Inserting batch 476000 to 477000
# → Inserting batch 477000 to 478000
# → Inserting batch 478000 to 479000
# → Inserting batch 479000 to 480000
# → Inserting batch 480000 to 481000
# → Inserting batch 481000 to 482000
# → Inserting batch 482000 to 483000
# → Inserting batch 483000 to 484000
# → Inserting batch 484000 to 485000
# → Inserting batch 485000 to 486000
# → Inserting batch 486000 to 487000
# → Inserting batch 487000 to 488000
# → Inserting batch 488000 to 489000
# → Inserting batch 489000 to 490000
# → Inserting batch 490000 to 491000
# → Inserting batch 491000 to 492000
# → Inserting batch 492000 to 493000
# → Inserting batch 493000 to 494000
# → Inserting batch 494000 to 495000
# → Inserting batch 495000 to 496000
# → Inserting batch 496000 to 497000
# → Inserting batch 497000 to 498000
# → Inserting batch 498000 to 499000
# → Inserting batch 499000 to 500000
# → Inserting batch 500000 to 501000
# → Inserting batch 501000 to 502000
# → Inserting batch 502000 to 503000
# → Inserting batch 503000 to 504000
# → Inserting batch 504000 to 505000
# → Inserting batch 505000 to 506000
# → Inserting batch 506000 to 507000
# → Inserting batch 507000 to 508000
# → Inserting batch 508000 to 509000
# → Inserting batch 509000 to 510000
# → Inserting batch 510000 to 511000
# → Inserting batch 511000 to 512000
# → Inserting batch 512000 to 513000
# → Inserting batch 513000 to 514000
# → Inserting batch 514000 to 515000
# → Inserting batch 515000 to 516000
# → Inserting batch 516000 to 517000
# → Inserting batch 517000 to 518000
# → Inserting batch 518000 to 519000
# → Inserting batch 519000 to 520000
# → Inserting batch 520000 to 521000
# → Inserting batch 521000 to 522000
# → Inserting batch 522000 to 523000
# → Inserting batch 523000 to 524000
# → Inserting batch 524000 to 525000
# → Inserting batch 525000 to 526000
# → Inserting batch 526000 to 527000
# → Inserting batch 527000 to 528000
# → Inserting batch 528000 to 529000
# → Inserting batch 529000 to 530000
# → Inserting batch 530000 to 531000
# → Inserting batch 531000 to 532000
# → Inserting batch 532000 to 533000
# → Inserting batch 533000 to 534000
# → Inserting batch 534000 to 535000
# → Inserting batch 535000 to 536000
# → Inserting batch 536000 to 537000
# → Inserting batch 537000 to 538000
# → Inserting batch 538000 to 539000
# → Inserting batch 539000 to 540000
# → Inserting batch 540000 to 541000
# → Inserting batch 541000 to 542000
# → Inserting batch 542000 to 543000
# → Inserting batch 543000 to 544000
# → Inserting batch 544000 to 545000
# → Inserting batch 545000 to 546000
# → Inserting batch 546000 to 547000
# → Inserting batch 547000 to 548000
# → Inserting batch 548000 to 549000
# → Inserting batch 549000 to 550000
# → Inserting batch 550000 to 551000
# → Inserting batch 551000 to 552000
# → Inserting batch 552000 to 553000
# → Inserting batch 553000 to 554000
# → Inserting batch 554000 to 555000
# → Inserting batch 555000 to 556000
# → Inserting batch 556000 to 557000
# → Inserting batch 557000 to 558000
# → Inserting batch 558000 to 559000
# → Inserting batch 559000 to 560000
# → Inserting batch 560000 to 561000
# → Inserting batch 561000 to 562000
# → Inserting batch 562000 to 563000
# → Inserting batch 563000 to 564000
# → Inserting batch 564000 to 565000
# → Inserting batch 565000 to 566000
# → Inserting batch 566000 to 567000
# → Inserting batch 567000 to 568000
# → Inserting batch 568000 to 569000
# → Inserting batch 569000 to 570000
# → Inserting batch 570000 to 571000
# → Inserting batch 571000 to 572000
# → Inserting batch 572000 to 573000
# → Inserting batch 573000 to 574000
# → Inserting batch 574000 to 575000
# → Inserting batch 575000 to 576000
# → Inserting batch 576000 to 577000
# → Inserting batch 577000 to 578000
# → Inserting batch 578000 to 579000
# → Inserting batch 579000 to 580000
# → Inserting batch 580000 to 581000
# → Inserting batch 581000 to 582000
# → Inserting batch 582000 to 583000
# → Inserting batch 583000 to 584000
# → Inserting batch 584000 to 585000
# → Inserting batch 585000 to 586000
# → Inserting batch 586000 to 587000
# → Inserting batch 587000 to 588000
# → Inserting batch 588000 to 589000
# → Inserting batch 589000 to 590000
# → Inserting batch 590000 to 591000
# → Inserting batch 591000 to 592000
# → Inserting batch 592000 to 593000
# → Inserting batch 593000 to 594000
# → Inserting batch 594000 to 595000
# → Inserting batch 595000 to 596000
# → Inserting batch 596000 to 597000
# → Inserting batch 597000 to 598000
# → Inserting batch 598000 to 599000
# → Inserting batch 599000 to 600000
# → Inserting batch 600000 to 601000
# → Inserting batch 601000 to 602000
# → Inserting batch 602000 to 603000
# → Inserting batch 603000 to 604000
# → Inserting batch 604000 to 605000
# → Inserting batch 605000 to 606000
# → Inserting batch 606000 to 607000
# → Inserting batch 607000 to 608000
# → Inserting batch 608000 to 609000
# → Inserting batch 609000 to 610000
# → Inserting batch 610000 to 611000
# → Inserting batch 611000 to 612000
# → Inserting batch 612000 to 613000
# → Inserting batch 613000 to 614000
# → Inserting batch 614000 to 615000
# → Inserting batch 615000 to 616000
# → Inserting batch 616000 to 617000
# → Inserting batch 617000 to 618000
# → Inserting batch 618000 to 619000
# → Inserting batch 619000 to 620000
# → Inserting batch 620000 to 621000
# → Inserting batch 621000 to 622000
# → Inserting batch 622000 to 623000
# → Inserting batch 623000 to 624000
# → Inserting batch 624000 to 625000
# → Inserting batch 625000 to 626000
# → Inserting batch 626000 to 627000
# → Inserting batch 627000 to 628000
# → Inserting batch 628000 to 629000
# → Inserting batch 629000 to 630000
# → Inserting batch 630000 to 631000
# → Inserting batch 631000 to 632000
# → Inserting batch 632000 to 633000
# → Inserting batch 633000 to 634000
# → Inserting batch 634000 to 635000
# → Inserting batch 635000 to 636000
# → Inserting batch 636000 to 637000
# → Inserting batch 637000 to 638000
# → Inserting batch 638000 to 639000
# → Inserting batch 639000 to 640000
# → Inserting batch 640000 to 641000
# → Inserting batch 641000 to 642000
# → Inserting batch 642000 to 643000
# → Inserting batch 643000 to 644000
# → Inserting batch 644000 to 645000
# → Inserting batch 645000 to 646000
# → Inserting batch 646000 to 647000
# → Inserting batch 647000 to 648000
# → Inserting batch 648000 to 649000
# → Inserting batch 649000 to 650000
# → Inserting batch 650000 to 651000
# → Inserting batch 651000 to 652000
# → Inserting batch 652000 to 653000
# → Inserting batch 653000 to 654000
# → Inserting batch 654000 to 655000
# → Inserting batch 655000 to 656000
# → Inserting batch 656000 to 657000
# → Inserting batch 657000 to 658000
# → Inserting batch 658000 to 659000
# → Inserting batch 659000 to 660000
# → Inserting batch 660000 to 661000
# → Inserting batch 661000 to 662000
# → Inserting batch 662000 to 663000
# → Inserting batch 663000 to 664000
# → Inserting batch 664000 to 665000
# → Inserting batch 665000 to 666000
# → Inserting batch 666000 to 667000
# → Inserting batch 667000 to 668000
# → Inserting batch 668000 to 669000
# → Inserting batch 669000 to 670000
# → Inserting batch 670000 to 671000
# → Inserting batch 671000 to 672000
# → Inserting batch 672000 to 673000
# → Inserting batch 673000 to 674000
# → Inserting batch 674000 to 675000
# → Inserting batch 675000 to 676000
# → Inserting batch 676000 to 677000
# → Inserting batch 677000 to 678000
# → Inserting batch 678000 to 679000
# → Inserting batch 679000 to 680000
# → Inserting batch 680000 to 681000
# → Inserting batch 681000 to 682000
# → Inserting batch 682000 to 683000
# → Inserting batch 683000 to 684000
# → Inserting batch 684000 to 685000
# → Inserting batch 685000 to 686000
# → Inserting batch 686000 to 687000
# → Inserting batch 687000 to 688000
# → Inserting batch 688000 to 689000
# → Inserting batch 689000 to 690000
# → Inserting batch 690000 to 691000
# → Inserting batch 691000 to 692000
# → Inserting batch 692000 to 693000
# → Inserting batch 693000 to 694000
# → Inserting batch 694000 to 695000
# → Inserting batch 695000 to 696000
# → Inserting batch 696000 to 697000
# → Inserting batch 697000 to 698000
# → Inserting batch 698000 to 699000
# → Inserting batch 699000 to 700000
# → Inserting batch 700000 to 701000
# → Inserting batch 701000 to 702000
# → Inserting batch 702000 to 703000
# → Inserting batch 703000 to 704000
# → Inserting batch 704000 to 705000
# → Inserting batch 705000 to 706000
# → Inserting batch 706000 to 707000
# → Inserting batch 707000 to 708000
# → Inserting batch 708000 to 709000
# → Inserting batch 709000 to 710000
# → Inserting batch 710000 to 711000
# → Inserting batch 711000 to 712000
# → Inserting batch 712000 to 713000
# → Inserting batch 713000 to 714000
# → Inserting batch 714000 to 715000
# → Inserting batch 715000 to 716000
# → Inserting batch 716000 to 717000
# → Inserting batch 717000 to 718000
# → Inserting batch 718000 to 719000
# → Inserting batch 719000 to 720000
# → Inserting batch 720000 to 721000
# → Inserting batch 721000 to 722000
# → Inserting batch 722000 to 723000
# → Inserting batch 723000 to 724000
# → Inserting batch 724000 to 725000
# → Inserting batch 725000 to 726000
# → Inserting batch 726000 to 727000
# → Inserting batch 727000 to 728000
# → Inserting batch 728000 to 729000
# → Inserting batch 729000 to 730000
# → Inserting batch 730000 to 731000
# → Inserting batch 731000 to 732000
# → Inserting batch 732000 to 733000
# → Inserting batch 733000 to 734000
# → Inserting batch 734000 to 735000
# → Inserting batch 735000 to 736000
# → Inserting batch 736000 to 737000
# → Inserting batch 737000 to 738000
# → Inserting batch 738000 to 739000
# → Inserting batch 739000 to 740000
# → Inserting batch 740000 to 741000
# → Inserting batch 741000 to 742000
# → Inserting batch 742000 to 743000
# → Inserting batch 743000 to 744000
# → Inserting batch 744000 to 745000
# → Inserting batch 745000 to 746000
# → Inserting batch 746000 to 747000
# → Inserting batch 747000 to 748000
# → Inserting batch 748000 to 749000
# → Inserting batch 749000 to 750000
# → Inserting batch 750000 to 751000
# → Inserting batch 751000 to 752000
# → Inserting batch 752000 to 753000
# → Inserting batch 753000 to 754000
# → Inserting batch 754000 to 755000
# → Inserting batch 755000 to 756000
# → Inserting batch 756000 to 757000
# → Inserting batch 757000 to 758000
# → Inserting batch 758000 to 759000
# → Inserting batch 759000 to 760000
# → Inserting batch 760000 to 761000
# → Inserting batch 761000 to 762000
# → Inserting batch 762000 to 763000
# → Inserting batch 763000 to 764000
# → Inserting batch 764000 to 765000
# → Inserting batch 765000 to 766000
# → Inserting batch 766000 to 767000
# → Inserting batch 767000 to 768000
# → Inserting batch 768000 to 769000
# → Inserting batch 769000 to 770000
# → Inserting batch 770000 to 771000
# → Inserting batch 771000 to 772000
# → Inserting batch 772000 to 773000
# → Inserting batch 773000 to 774000
# → Inserting batch 774000 to 775000
# → Inserting batch 775000 to 776000
# → Inserting batch 776000 to 777000
# → Inserting batch 777000 to 778000
# → Inserting batch 778000 to 779000
# → Inserting batch 779000 to 780000
# → Inserting batch 780000 to 781000
# → Inserting batch 781000 to 782000
# → Inserting batch 782000 to 783000
# → Inserting batch 783000 to 784000
# → Inserting batch 784000 to 785000
# → Inserting batch 785000 to 786000
# → Inserting batch 786000 to 787000
# → Inserting batch 787000 to 788000
# → Inserting batch 788000 to 789000
# → Inserting batch 789000 to 790000
# → Inserting batch 790000 to 791000
# → Inserting batch 791000 to 792000
# → Inserting batch 792000 to 793000
# → Inserting batch 793000 to 794000
# → Inserting batch 794000 to 795000
# → Inserting batch 795000 to 796000
# → Inserting batch 796000 to 797000
# → Inserting batch 797000 to 798000
# → Inserting batch 798000 to 799000
# → Inserting batch 799000 to 800000
# → Inserting batch 800000 to 801000
# → Inserting batch 801000 to 802000
# → Inserting batch 802000 to 803000
# → Inserting batch 803000 to 804000
# → Inserting batch 804000 to 805000
# → Inserting batch 805000 to 806000
# → Inserting batch 806000 to 807000
# → Inserting batch 807000 to 808000
# → Inserting batch 808000 to 809000
# → Inserting batch 809000 to 810000
# → Inserting batch 810000 to 811000
# → Inserting batch 811000 to 812000
# → Inserting batch 812000 to 813000
# → Inserting batch 813000 to 814000
# → Inserting batch 814000 to 815000
# → Inserting batch 815000 to 816000
# → Inserting batch 816000 to 817000
# → Inserting batch 817000 to 818000
# → Inserting batch 818000 to 819000
# → Inserting batch 819000 to 820000
# → Inserting batch 820000 to 821000
# → Inserting batch 821000 to 822000
# → Inserting batch 822000 to 823000
# → Inserting batch 823000 to 824000
# → Inserting batch 824000 to 825000
# → Inserting batch 825000 to 826000
# → Inserting batch 826000 to 827000
# → Inserting batch 827000 to 828000
# → Inserting batch 828000 to 829000
# → Inserting batch 829000 to 830000
# → Inserting batch 830000 to 831000
# → Inserting batch 831000 to 832000
# → Inserting batch 832000 to 833000
# → Inserting batch 833000 to 834000
# → Inserting batch 834000 to 835000
# → Inserting batch 835000 to 836000
# → Inserting batch 836000 to 837000
# → Inserting batch 837000 to 838000
# → Inserting batch 838000 to 839000
# → Inserting batch 839000 to 840000
# → Inserting batch 840000 to 841000
# → Inserting batch 841000 to 842000
# → Inserting batch 842000 to 843000
# → Inserting batch 843000 to 844000
# → Inserting batch 844000 to 845000
# → Inserting batch 845000 to 846000
# → Inserting batch 846000 to 847000
# → Inserting batch 847000 to 848000
# → Inserting batch 848000 to 849000
# → Inserting batch 849000 to 850000
# → Inserting batch 850000 to 851000
# → Inserting batch 851000 to 852000
# → Inserting batch 852000 to 853000
# → Inserting batch 853000 to 854000
# → Inserting batch 854000 to 855000
# → Inserting batch 855000 to 856000
# → Inserting batch 856000 to 857000
# → Inserting batch 857000 to 858000
# → Inserting batch 858000 to 859000
# → Inserting batch 859000 to 860000
# → Inserting batch 860000 to 861000
# → Inserting batch 861000 to 862000
# → Inserting batch 862000 to 863000
# → Inserting batch 863000 to 864000
# → Inserting batch 864000 to 865000
# → Inserting batch 865000 to 866000
# → Inserting batch 866000 to 867000
# → Inserting batch 867000 to 868000
# → Inserting batch 868000 to 869000
# → Inserting batch 869000 to 870000
# → Inserting batch 870000 to 871000
# → Inserting batch 871000 to 872000
# → Inserting batch 872000 to 873000
# → Inserting batch 873000 to 874000
# → Inserting batch 874000 to 875000
# → Inserting batch 875000 to 876000
# → Inserting batch 876000 to 877000
# → Inserting batch 877000 to 878000
# → Inserting batch 878000 to 879000
# → Inserting batch 879000 to 880000
# → Inserting batch 880000 to 881000
# → Inserting batch 881000 to 882000
# → Inserting batch 882000 to 883000
# → Inserting batch 883000 to 884000
# → Inserting batch 884000 to 885000
# → Inserting batch 885000 to 886000
# → Inserting batch 886000 to 887000
# → Inserting batch 887000 to 888000
# → Inserting batch 888000 to 889000
# → Inserting batch 889000 to 890000
# → Inserting batch 890000 to 891000
# → Inserting batch 891000 to 892000
# → Inserting batch 892000 to 893000
# → Inserting batch 893000 to 894000
# → Inserting batch 894000 to 895000
# → Inserting batch 895000 to 896000
# → Inserting batch 896000 to 897000
# → Inserting batch 897000 to 898000
# → Inserting batch 898000 to 899000
# → Inserting batch 899000 to 900000
# → Inserting batch 900000 to 901000
# → Inserting batch 901000 to 902000
# → Inserting batch 902000 to 903000
# → Inserting batch 903000 to 904000
# → Inserting batch 904000 to 905000
# → Inserting batch 905000 to 906000
# → Inserting batch 906000 to 907000
# → Inserting batch 907000 to 908000
# → Inserting batch 908000 to 909000
# → Inserting batch 909000 to 910000
# → Inserting batch 910000 to 911000
# → Inserting batch 911000 to 912000
# → Inserting batch 912000 to 913000
# → Inserting batch 913000 to 914000
# → Inserting batch 914000 to 915000
# → Inserting batch 915000 to 916000
# → Inserting batch 916000 to 917000
# → Inserting batch 917000 to 918000
# → Inserting batch 918000 to 919000
# → Inserting batch 919000 to 920000
# → Inserting batch 920000 to 921000
# → Inserting batch 921000 to 922000
# → Inserting batch 922000 to 923000
# → Inserting batch 923000 to 924000
# → Inserting batch 924000 to 925000
# → Inserting batch 925000 to 926000
# → Inserting batch 926000 to 927000
# → Inserting batch 927000 to 928000
# → Inserting batch 928000 to 929000
# → Inserting batch 929000 to 930000
# → Inserting batch 930000 to 931000
# → Inserting batch 931000 to 932000
# → Inserting batch 932000 to 933000
# → Inserting batch 933000 to 934000
# → Inserting batch 934000 to 935000
# → Inserting batch 935000 to 936000
# → Inserting batch 936000 to 937000
# → Inserting batch 937000 to 938000
# → Inserting batch 938000 to 939000
# → Inserting batch 939000 to 940000
# → Inserting batch 940000 to 941000
# → Inserting batch 941000 to 942000
# → Inserting batch 942000 to 943000
# → Inserting batch 943000 to 944000
# → Inserting batch 944000 to 945000
# → Inserting batch 945000 to 946000
# → Inserting batch 946000 to 947000
# → Inserting batch 947000 to 948000
# → Inserting batch 948000 to 949000
# → Inserting batch 949000 to 950000
# → Inserting batch 950000 to 951000
# → Inserting batch 951000 to 952000
# → Inserting batch 952000 to 953000
# → Inserting batch 953000 to 954000
# → Inserting batch 954000 to 955000
# → Inserting batch 955000 to 956000
# → Inserting batch 956000 to 957000
# → Inserting batch 957000 to 958000
# → Inserting batch 958000 to 959000
# → Inserting batch 959000 to 960000
# → Inserting batch 960000 to 961000
# → Inserting batch 961000 to 962000
# → Inserting batch 962000 to 963000
# → Inserting batch 963000 to 964000
# → Inserting batch 964000 to 965000
# → Inserting batch 965000 to 966000
# → Inserting batch 966000 to 967000
# → Inserting batch 967000 to 968000
# → Inserting batch 968000 to 969000
# → Inserting batch 969000 to 970000
# → Inserting batch 970000 to 971000
# → Inserting batch 971000 to 972000
# → Inserting batch 972000 to 973000
# → Inserting batch 973000 to 974000
# → Inserting batch 974000 to 975000
# → Inserting batch 975000 to 976000
# → Inserting batch 976000 to 977000
# → Inserting batch 977000 to 978000
# → Inserting batch 978000 to 979000
# → Inserting batch 979000 to 980000
# → Inserting batch 980000 to 981000
# → Inserting batch 981000 to 982000
# → Inserting batch 982000 to 983000
# → Inserting batch 983000 to 984000
# → Inserting batch 984000 to 985000
# → Inserting batch 985000 to 986000
# → Inserting batch 986000 to 987000
# → Inserting batch 987000 to 988000
# → Inserting batch 988000 to 989000
# → Inserting batch 989000 to 990000
# → Inserting batch 990000 to 991000
# → Inserting batch 991000 to 992000
# → Inserting batch 992000 to 993000
# → Inserting batch 993000 to 994000
# → Inserting batch 994000 to 995000
# → Inserting batch 995000 to 996000
# → Inserting batch 996000 to 997000
# → Inserting batch 997000 to 998000
# → Inserting batch 998000 to 999000
# → Inserting batch 999000 to 1000000
# → Inserting batch 1000000 to 1001000
# → Inserting batch 1001000 to 1002000
# → Inserting batch 1002000 to 1003000
# → Inserting batch 1003000 to 1004000
# → Inserting batch 1004000 to 1005000
# → Inserting batch 1005000 to 1006000
# → Inserting batch 1006000 to 1007000
# → Inserting batch 1007000 to 1008000
# → Inserting batch 1008000 to 1009000
# → Inserting batch 1009000 to 1010000
# → Inserting batch 1010000 to 1011000
# → Inserting batch 1011000 to 1012000
# → Inserting batch 1012000 to 1013000
# → Inserting batch 1013000 to 1014000
# → Inserting batch 1014000 to 1015000
# → Inserting batch 1015000 to 1016000
# → Inserting batch 1016000 to 1017000
# → Inserting batch 1017000 to 1018000
# → Inserting batch 1018000 to 1019000
# → Inserting batch 1019000 to 1020000
# → Inserting batch 1020000 to 1021000
# → Inserting batch 1021000 to 1022000
# → Inserting batch 1022000 to 1023000
# → Inserting batch 1023000 to 1024000
# → Inserting batch 1024000 to 1025000
# → Inserting batch 1025000 to 1026000
# → Inserting batch 1026000 to 1027000
# → Inserting batch 1027000 to 1028000
# → Inserting batch 1028000 to 1029000
# → Inserting batch 1029000 to 1030000
# → Inserting batch 1030000 to 1031000
# → Inserting batch 1031000 to 1032000
# → Inserting batch 1032000 to 1033000
# → Inserting batch 1033000 to 1034000
# → Inserting batch 1034000 to 1035000
# → Inserting batch 1035000 to 1036000
# → Inserting batch 1036000 to 1037000
# → Inserting batch 1037000 to 1038000
# → Inserting batch 1038000 to 1039000
# → Inserting batch 1039000 to 1040000
# → Inserting batch 1040000 to 1041000
# → Inserting batch 1041000 to 1042000
# → Inserting batch 1042000 to 1043000
# → Inserting batch 1043000 to 1044000
# → Inserting batch 1044000 to 1045000
# → Inserting batch 1045000 to 1046000
# → Inserting batch 1046000 to 1047000
# → Inserting batch 1047000 to 1048000
# → Inserting batch 1048000 to 1049000
# → Inserting batch 1049000 to 1050000
# → Inserting batch 1050000 to 1051000
# → Inserting batch 1051000 to 1052000
# → Inserting batch 1052000 to 1053000
# → Inserting batch 1053000 to 1054000
# → Inserting batch 1054000 to 1055000
# → Inserting batch 1055000 to 1056000
# → Inserting batch 1056000 to 1057000
# → Inserting batch 1057000 to 1058000
# → Inserting batch 1058000 to 1059000
# → Inserting batch 1059000 to 1060000
# → Inserting batch 1060000 to 1061000
# → Inserting batch 1061000 to 1062000
# → Inserting batch 1062000 to 1063000
# → Inserting batch 1063000 to 1064000
# → Inserting batch 1064000 to 1065000
# → Inserting batch 1065000 to 1066000
# → Inserting batch 1066000 to 1067000
# → Inserting batch 1067000 to 1068000
# → Inserting batch 1068000 to 1069000
# → Inserting batch 1069000 to 1070000
# → Inserting batch 1070000 to 1071000
# → Inserting batch 1071000 to 1072000
# → Inserting batch 1072000 to 1073000
# → Inserting batch 1073000 to 1074000
# → Inserting batch 1074000 to 1075000
# → Inserting batch 1075000 to 1076000
# → Inserting batch 1076000 to 1077000
# → Inserting batch 1077000 to 1078000
# → Inserting batch 1078000 to 1079000
# → Inserting batch 1079000 to 1080000
# → Inserting batch 1080000 to 1081000
# → Inserting batch 1081000 to 1082000
# → Inserting batch 1082000 to 1083000
# → Inserting batch 1083000 to 1084000
# → Inserting batch 1084000 to 1085000
# → Inserting batch 1085000 to 1086000
# → Inserting batch 1086000 to 1087000
# → Inserting batch 1087000 to 1088000
# → Inserting batch 1088000 to 1089000
# → Inserting batch 1089000 to 1090000
# → Inserting batch 1090000 to 1091000
# → Inserting batch 1091000 to 1092000
# → Inserting batch 1092000 to 1093000
# → Inserting batch 1093000 to 1094000
# → Inserting batch 1094000 to 1095000
# → Inserting batch 1095000 to 1096000
# → Inserting batch 1096000 to 1097000
# → Inserting batch 1097000 to 1098000
# → Inserting batch 1098000 to 1099000
# → Inserting batch 1099000 to 1100000
# → Inserting batch 1100000 to 1101000
# → Inserting batch 1101000 to 1102000
# → Inserting batch 1102000 to 1103000
# → Inserting batch 1103000 to 1104000
# → Inserting batch 1104000 to 1105000
# → Inserting batch 1105000 to 1106000
# → Inserting batch 1106000 to 1107000
# → Inserting batch 1107000 to 1108000
# → Inserting batch 1108000 to 1109000
# → Inserting batch 1109000 to 1110000
# → Inserting batch 1110000 to 1111000
# → Inserting batch 1111000 to 1112000
# → Inserting batch 1112000 to 1113000
# → Inserting batch 1113000 to 1114000
# → Inserting batch 1114000 to 1115000
# → Inserting batch 1115000 to 1116000
# → Inserting batch 1116000 to 1117000
# → Inserting batch 1117000 to 1118000
# → Inserting batch 1118000 to 1119000
# → Inserting batch 1119000 to 1120000
# → Inserting batch 1120000 to 1121000
# → Inserting batch 1121000 to 1122000
# → Inserting batch 1122000 to 1123000
# → Inserting batch 1123000 to 1124000
# → Inserting batch 1124000 to 1125000
# → Inserting batch 1125000 to 1126000
# → Inserting batch 1126000 to 1127000
# → Inserting batch 1127000 to 1128000
# → Inserting batch 1128000 to 1129000
# → Inserting batch 1129000 to 1130000
# → Inserting batch 1130000 to 1131000
# → Inserting batch 1131000 to 1132000
# → Inserting batch 1132000 to 1133000
# → Inserting batch 1133000 to 1134000
# → Inserting batch 1134000 to 1135000
# → Inserting batch 1135000 to 1136000
# → Inserting batch 1136000 to 1137000
# → Inserting batch 1137000 to 1138000
# → Inserting batch 1138000 to 1139000
# → Inserting batch 1139000 to 1140000
# → Inserting batch 1140000 to 1141000
# → Inserting batch 1141000 to 1142000
# → Inserting batch 1142000 to 1143000
# → Inserting batch 1143000 to 1144000
# → Inserting batch 1144000 to 1145000
# → Inserting batch 1145000 to 1146000
# → Inserting batch 1146000 to 1147000
# → Inserting batch 1147000 to 1148000
# → Inserting batch 1148000 to 1149000
# → Inserting batch 1149000 to 1150000
# → Inserting batch 1150000 to 1151000
# → Inserting batch 1151000 to 1152000
# → Inserting batch 1152000 to 1153000
# → Inserting batch 1153000 to 1154000
# → Inserting batch 1154000 to 1155000
# → Inserting batch 1155000 to 1156000
# → Inserting batch 1156000 to 1157000
# → Inserting batch 1157000 to 1158000
# → Inserting batch 1158000 to 1159000
# → Inserting batch 1159000 to 1160000
# → Inserting batch 1160000 to 1161000
# → Inserting batch 1161000 to 1162000
# → Inserting batch 1162000 to 1163000
# → Inserting batch 1163000 to 1164000
# → Inserting batch 1164000 to 1165000
# → Inserting batch 1165000 to 1166000
# → Inserting batch 1166000 to 1167000
# → Inserting batch 1167000 to 1168000
# → Inserting batch 1168000 to 1169000
# → Inserting batch 1169000 to 1170000
# → Inserting batch 1170000 to 1171000
# → Inserting batch 1171000 to 1172000
# → Inserting batch 1172000 to 1173000
# → Inserting batch 1173000 to 1174000
# → Inserting batch 1174000 to 1175000
# → Inserting batch 1175000 to 1176000
# → Inserting batch 1176000 to 1177000
# → Inserting batch 1177000 to 1178000
# → Inserting batch 1178000 to 1179000
# → Inserting batch 1179000 to 1180000
# → Inserting batch 1180000 to 1181000
# → Inserting batch 1181000 to 1182000
# → Inserting batch 1182000 to 1183000
# → Inserting batch 1183000 to 1184000
# → Inserting batch 1184000 to 1185000
# → Inserting batch 1185000 to 1186000
# → Inserting batch 1186000 to 1187000
# → Inserting batch 1187000 to 1188000
# → Inserting batch 1188000 to 1189000
# → Inserting batch 1189000 to 1190000
# → Inserting batch 1190000 to 1191000
# → Inserting batch 1191000 to 1192000
# → Inserting batch 1192000 to 1193000
# → Inserting batch 1193000 to 1194000
# → Inserting batch 1194000 to 1195000
# → Inserting batch 1195000 to 1196000
# → Inserting batch 1196000 to 1197000
# → Inserting batch 1197000 to 1198000
# → Inserting batch 1198000 to 1199000
# → Inserting batch 1199000 to 1200000
# → Inserting batch 1200000 to 1201000
# → Inserting batch 1201000 to 1202000
# → Inserting batch 1202000 to 1203000
# → Inserting batch 1203000 to 1204000
# → Inserting batch 1204000 to 1205000
# → Inserting batch 1205000 to 1206000
# → Inserting batch 1206000 to 1207000
# → Inserting batch 1207000 to 1208000
# → Inserting batch 1208000 to 1209000
# → Inserting batch 1209000 to 1210000
# → Inserting batch 1210000 to 1211000
# → Inserting batch 1211000 to 1212000
# → Inserting batch 1212000 to 1213000
# → Inserting batch 1213000 to 1214000
# → Inserting batch 1214000 to 1215000
# → Inserting batch 1215000 to 1216000
# → Inserting batch 1216000 to 1217000
# → Inserting batch 1217000 to 1218000
# → Inserting batch 1218000 to 1219000
# → Inserting batch 1219000 to 1220000
# → Inserting batch 1220000 to 1221000
# → Inserting batch 1221000 to 1222000
# → Inserting batch 1222000 to 1223000
# → Inserting batch 1223000 to 1224000
# → Inserting batch 1224000 to 1225000
# → Inserting batch 1225000 to 1226000
# → Inserting batch 1226000 to 1227000
# → Inserting batch 1227000 to 1228000
# → Inserting batch 1228000 to 1229000
# → Inserting batch 1229000 to 1230000
# → Inserting batch 1230000 to 1231000
# → Inserting batch 1231000 to 1232000
# → Inserting batch 1232000 to 1233000
# → Inserting batch 1233000 to 1234000
# → Inserting batch 1234000 to 1235000
# → Inserting batch 1235000 to 1236000
# → Inserting batch 1236000 to 1237000
# → Inserting batch 1237000 to 1238000
# → Inserting batch 1238000 to 1239000
# → Inserting batch 1239000 to 1240000
# → Inserting batch 1240000 to 1241000
# → Inserting batch 1241000 to 1242000
# → Inserting batch 1242000 to 1243000
# → Inserting batch 1243000 to 1244000
# → Inserting batch 1244000 to 1245000
# → Inserting batch 1245000 to 1246000
# → Inserting batch 1246000 to 1247000
# → Inserting batch 1247000 to 1248000
# → Inserting batch 1248000 to 1249000
# → Inserting batch 1249000 to 1250000
# → Inserting batch 1250000 to 1251000
# → Inserting batch 1251000 to 1252000
# → Inserting batch 1252000 to 1253000
# → Inserting batch 1253000 to 1254000
# → Inserting batch 1254000 to 1255000
# → Inserting batch 1255000 to 1256000
# → Inserting batch 1256000 to 1257000
# → Inserting batch 1257000 to 1258000
# → Inserting batch 1258000 to 1259000
# → Inserting batch 1259000 to 1260000
# → Inserting batch 1260000 to 1261000
# → Inserting batch 1261000 to 1262000
# → Inserting batch 1262000 to 1263000
# → Inserting batch 1263000 to 1264000
# → Inserting batch 1264000 to 1265000
# → Inserting batch 1265000 to 1266000
# → Inserting batch 1266000 to 1267000
# → Inserting batch 1267000 to 1268000
# → Inserting batch 1268000 to 1269000
# → Inserting batch 1269000 to 1270000
# → Inserting batch 1270000 to 1271000
# → Inserting batch 1271000 to 1272000
# → Inserting batch 1272000 to 1273000
# → Inserting batch 1273000 to 1274000
# → Inserting batch 1274000 to 1275000
# → Inserting batch 1275000 to 1276000
# → Inserting batch 1276000 to 1277000
# → Inserting batch 1277000 to 1278000
# → Inserting batch 1278000 to 1279000
# → Inserting batch 1279000 to 1280000
# → Inserting batch 1280000 to 1281000
# → Inserting batch 1281000 to 1282000
# → Inserting batch 1282000 to 1283000
# → Inserting batch 1283000 to 1284000
# → Inserting batch 1284000 to 1285000
# → Inserting batch 1285000 to 1286000
# → Inserting batch 1286000 to 1287000
# → Inserting batch 1287000 to 1288000
# → Inserting batch 1288000 to 1289000
# → Inserting batch 1289000 to 1290000
# → Inserting batch 1290000 to 1291000
# → Inserting batch 1291000 to 1292000
# → Inserting batch 1292000 to 1293000
# ...
# → Inserting batch 4649000 to 4650000
# → Inserting batch 4650000 to 4651000
# → Inserting batch 4651000 to 4652000
# → Inserting batch 4652000 to 4653000
# → Inserting batch 4653000 to 4654000
# → Inserting batch 4654000 to 4655000
# → Inserting batch 4655000 to 4656000
# → Inserting batch 4656000 to 4657000
# → Inserting batch 4657000 to 4658000
# → Inserting batch 4658000 to 4659000
# → Inserting batch 4659000 to 4660000
# → Inserting batch 4660000 to 4661000
# → Inserting batch 4661000 to 4662000
# → Inserting batch 4662000 to 4663000
# → Inserting batch 4663000 to 4664000
# → Inserting batch 4664000 to 4665000
# → Inserting batch 4665000 to 4666000
# → Inserting batch 4666000 to 4667000
# → Inserting batch 4667000 to 4668000
# → Inserting batch 4668000 to 4669000
# → Inserting batch 4669000 to 4670000
# → Inserting batch 4670000 to 4671000
# → Inserting batch 4671000 to 4672000
# → Inserting batch 4672000 to 4673000
# → Inserting batch 4673000 to 4674000
# → Inserting batch 4674000 to 4675000
# → Inserting batch 4675000 to 4676000
# → Inserting batch 4676000 to 4677000
# → Inserting batch 4677000 to 4678000
# → Inserting batch 4678000 to 4679000
# → Inserting batch 4679000 to 4680000
# → Inserting batch 4680000 to 4681000
# → Inserting batch 4681000 to 4682000
# → Inserting batch 4682000 to 4683000
# → Inserting batch 4683000 to 4684000
# → Inserting batch 4684000 to 4685000
# → Inserting batch 4685000 to 4686000
# → Inserting batch 4686000 to 4687000
# → Inserting batch 4687000 to 4688000
# → Inserting batch 4688000 to 4689000
# → Inserting batch 4689000 to 4690000
# → Inserting batch 4690000 to 4691000
# → Inserting batch 4691000 to 4692000
# → Inserting batch 4692000 to 4693000
# → Inserting batch 4693000 to 4694000
# → Inserting batch 4694000 to 4695000
# → Inserting batch 4695000 to 4696000
# → Inserting batch 4696000 to 4697000
# → Inserting batch 4697000 to 4698000
# → Inserting batch 4698000 to 4699000
# → Inserting batch 4699000 to 4700000
# → Inserting batch 4700000 to 4701000
# → Inserting batch 4701000 to 4702000
# → Inserting batch 4702000 to 4703000
# → Inserting batch 4703000 to 4704000
# → Inserting batch 4704000 to 4705000
# → Inserting batch 4705000 to 4706000
# → Inserting batch 4706000 to 4707000
# → Inserting batch 4707000 to 4708000
# → Inserting batch 4708000 to 4709000
# → Inserting batch 4709000 to 4710000
# → Inserting batch 4710000 to 4711000
# → Inserting batch 4711000 to 4712000
# → Inserting batch 4712000 to 4713000
# → Inserting batch 4713000 to 4714000
# → Inserting batch 4714000 to 4715000
# → Inserting batch 4715000 to 4716000
# → Inserting batch 4716000 to 4717000
# → Inserting batch 4717000 to 4718000
# → Inserting batch 4718000 to 4719000
# → Inserting batch 4719000 to 4720000
# → Inserting batch 4720000 to 4721000
# → Inserting batch 4721000 to 4722000
# → Inserting batch 4722000 to 4723000
# → Inserting batch 4723000 to 4724000
# → Inserting batch 4724000 to 4725000
# → Inserting batch 4725000 to 4726000
# → Inserting batch 4726000 to 4727000
# → Inserting batch 4727000 to 4728000
# → Inserting batch 4728000 to 4729000
# → Inserting batch 4729000 to 4730000
# → Inserting batch 4730000 to 4731000
# → Inserting batch 4731000 to 4732000
# → Inserting batch 4732000 to 4733000
# → Inserting batch 4733000 to 4734000
# → Inserting batch 4734000 to 4735000
# → Inserting batch 4735000 to 4736000
# → Inserting batch 4736000 to 4737000
# → Inserting batch 4737000 to 4738000
# → Inserting batch 4738000 to 4739000
# → Inserting batch 4739000 to 4740000
# → Inserting batch 4740000 to 4741000
# → Inserting batch 4741000 to 4742000
# → Inserting batch 4742000 to 4743000
# → Inserting batch 4743000 to 4744000
# → Inserting batch 4744000 to 4745000
# → Inserting batch 4745000 to 4746000
# → Inserting batch 4746000 to 4747000
# → Inserting batch 4747000 to 4748000
# → Inserting batch 4748000 to 4749000
# → Inserting batch 4749000 to 4750000
# → Inserting batch 4750000 to 4751000
# → Inserting batch 4751000 to 4752000
# → Inserting batch 4752000 to 4753000
# → Inserting batch 4753000 to 4754000
# → Inserting batch 4754000 to 4755000
# → Inserting batch 4755000 to 4756000
# → Inserting batch 4756000 to 4757000
# → Inserting batch 4757000 to 4758000
# → Inserting batch 4758000 to 4759000
# → Inserting batch 4759000 to 4760000
# → Inserting batch 4760000 to 4761000
# → Inserting batch 4761000 to 4762000
# → Inserting batch 4762000 to 4763000
# → Inserting batch 4763000 to 4764000
# → Inserting batch 4764000 to 4765000
# → Inserting batch 4765000 to 4766000
# → Inserting batch 4766000 to 4767000
# → Inserting batch 4767000 to 4768000
# → Inserting batch 4768000 to 4769000
# → Inserting batch 4769000 to 4770000
# → Inserting batch 4770000 to 4771000
# → Inserting batch 4771000 to 4772000
# → Inserting batch 4772000 to 4773000
# → Inserting batch 4773000 to 4774000
# → Inserting batch 4774000 to 4775000
# → Inserting batch 4775000 to 4776000
# → Inserting batch 4776000 to 4777000
# → Inserting batch 4777000 to 4778000
# → Inserting batch 4778000 to 4779000
# → Inserting batch 4779000 to 4780000
# → Inserting batch 4780000 to 4781000
# → Inserting batch 4781000 to 4782000
# → Inserting batch 4782000 to 4783000
# → Inserting batch 4783000 to 4784000
# → Inserting batch 4784000 to 4785000
# → Inserting batch 4785000 to 4786000
# → Inserting batch 4786000 to 4787000
# → Inserting batch 4787000 to 4788000
# → Inserting batch 4788000 to 4789000
# → Inserting batch 4789000 to 4790000
# → Inserting batch 4790000 to 4791000
# → Inserting batch 4791000 to 4792000
# → Inserting batch 4792000 to 4793000
# → Inserting batch 4793000 to 4794000
# → Inserting batch 4794000 to 4795000
# → Inserting batch 4795000 to 4796000
# → Inserting batch 4796000 to 4797000
# → Inserting batch 4797000 to 4798000
# → Inserting batch 4798000 to 4799000
# → Inserting batch 4799000 to 4800000
# → Inserting batch 4800000 to 4801000
# → Inserting batch 4801000 to 4802000
# → Inserting batch 4802000 to 4803000
# → Inserting batch 4803000 to 4804000
# → Inserting batch 4804000 to 4805000
# → Inserting batch 4805000 to 4806000
# → Inserting batch 4806000 to 4807000
# → Inserting batch 4807000 to 4808000
# → Inserting batch 4808000 to 4809000
# → Inserting batch 4809000 to 4810000
# → Inserting batch 4810000 to 4811000
# → Inserting batch 4811000 to 4812000
# → Inserting batch 4812000 to 4813000
# → Inserting batch 4813000 to 4814000
# → Inserting batch 4814000 to 4815000
# → Inserting batch 4815000 to 4816000
# → Inserting batch 4816000 to 4817000
# → Inserting batch 4817000 to 4818000
# → Inserting batch 4818000 to 4819000
# → Inserting batch 4819000 to 4820000
# → Inserting batch 4820000 to 4821000
# → Inserting batch 4821000 to 4822000
# → Inserting batch 4822000 to 4823000
# → Inserting batch 4823000 to 4824000
# → Inserting batch 4824000 to 4825000
# → Inserting batch 4825000 to 4826000
# → Inserting batch 4826000 to 4827000
# → Inserting batch 4827000 to 4828000
# → Inserting batch 4828000 to 4829000
# → Inserting batch 4829000 to 4830000
# → Inserting batch 4830000 to 4831000
# → Inserting batch 4831000 to 4832000
# → Inserting batch 4832000 to 4833000
# → Inserting batch 4833000 to 4834000
# → Inserting batch 4834000 to 4835000
# → Inserting batch 4835000 to 4836000
# → Inserting batch 4836000 to 4837000
# → Inserting batch 4837000 to 4838000
# → Inserting batch 4838000 to 4839000
# → Inserting batch 4839000 to 4840000
# → Inserting batch 4840000 to 4841000
# → Inserting batch 4841000 to 4842000
# → Inserting batch 4842000 to 4843000
# → Inserting batch 4843000 to 4844000
# → Inserting batch 4844000 to 4845000
# → Inserting batch 4845000 to 4846000
# → Inserting batch 4846000 to 4847000
# → Inserting batch 4847000 to 4848000
# → Inserting batch 4848000 to 4849000
# → Inserting batch 4849000 to 4850000
# → Inserting batch 4850000 to 4851000
# → Inserting batch 4851000 to 4852000
# → Inserting batch 4852000 to 4853000
# → Inserting batch 4853000 to 4854000
# → Inserting batch 4854000 to 4855000
# → Inserting batch 4855000 to 4856000
# → Inserting batch 4856000 to 4857000
# → Inserting batch 4857000 to 4858000
# → Inserting batch 4858000 to 4859000
# → Inserting batch 4859000 to 4860000
# → Inserting batch 4860000 to 4861000
# → Inserting batch 4861000 to 4862000
# → Inserting batch 4862000 to 4863000
# → Inserting batch 4863000 to 4864000
# → Inserting batch 4864000 to 4865000
# → Inserting batch 4865000 to 4866000
# → Inserting batch 4866000 to 4867000
# → Inserting batch 4867000 to 4868000
# → Inserting batch 4868000 to 4869000
# → Inserting batch 4869000 to 4870000
# → Inserting batch 4870000 to 4871000
# → Inserting batch 4871000 to 4872000
# → Inserting batch 4872000 to 4873000
# → Inserting batch 4873000 to 4874000
# → Inserting batch 4874000 to 4875000
# → Inserting batch 4875000 to 4876000
# → Inserting batch 4876000 to 4877000
# → Inserting batch 4877000 to 4878000
# → Inserting batch 4878000 to 4879000
# → Inserting batch 4879000 to 4880000
# → Inserting batch 4880000 to 4881000
# → Inserting batch 4881000 to 4882000
# → Inserting batch 4882000 to 4883000
# → Inserting batch 4883000 to 4884000
# → Inserting batch 4884000 to 4885000
# → Inserting batch 4885000 to 4886000
# → Inserting batch 4886000 to 4887000
# → Inserting batch 4887000 to 4888000
# → Inserting batch 4888000 to 4889000
# → Inserting batch 4889000 to 4890000
# → Inserting batch 4890000 to 4891000
# → Inserting batch 4891000 to 4892000
# → Inserting batch 4892000 to 4893000
# → Inserting batch 4893000 to 4894000
# → Inserting batch 4894000 to 4895000
# → Inserting batch 4895000 to 4896000
# → Inserting batch 4896000 to 4897000
# → Inserting batch 4897000 to 4898000
# → Inserting batch 4898000 to 4899000
# → Inserting batch 4899000 to 4900000
# → Inserting batch 4900000 to 4901000
# → Inserting batch 4901000 to 4902000
# → Inserting batch 4902000 to 4903000
# → Inserting batch 4903000 to 4904000
# → Inserting batch 4904000 to 4905000
# → Inserting batch 4905000 to 4906000
# → Inserting batch 4906000 to 4907000
# → Inserting batch 4907000 to 4908000
# → Inserting batch 4908000 to 4909000
# → Inserting batch 4909000 to 4910000
# → Inserting batch 4910000 to 4911000
# → Inserting batch 4911000 to 4912000
# → Inserting batch 4912000 to 4913000
# → Inserting batch 4913000 to 4914000
# → Inserting batch 4914000 to 4915000
# → Inserting batch 4915000 to 4916000
# → Inserting batch 4916000 to 4917000
# → Inserting batch 4917000 to 4918000
# → Inserting batch 4918000 to 4919000
# → Inserting batch 4919000 to 4920000
# → Inserting batch 4920000 to 4921000
# → Inserting batch 4921000 to 4922000
# → Inserting batch 4922000 to 4923000
# → Inserting batch 4923000 to 4924000
# → Inserting batch 4924000 to 4925000
# → Inserting batch 4925000 to 4926000
# → Inserting batch 4926000 to 4927000
# → Inserting batch 4927000 to 4928000
# → Inserting batch 4928000 to 4929000
# → Inserting batch 4929000 to 4930000
# → Inserting batch 4930000 to 4931000
# → Inserting batch 4931000 to 4932000
# → Inserting batch 4932000 to 4933000
# → Inserting batch 4933000 to 4934000
# → Inserting batch 4934000 to 4935000
# → Inserting batch 4935000 to 4936000
# → Inserting batch 4936000 to 4937000
# → Inserting batch 4937000 to 4938000
# → Inserting batch 4938000 to 4939000
# → Inserting batch 4939000 to 4940000
# → Inserting batch 4940000 to 4941000
# → Inserting batch 4941000 to 4942000
# → Inserting batch 4942000 to 4943000
# → Inserting batch 4943000 to 4944000
# → Inserting batch 4944000 to 4945000
# → Inserting batch 4945000 to 4946000
# → Inserting batch 4946000 to 4947000
# → Inserting batch 4947000 to 4948000
# → Inserting batch 4948000 to 4949000
# → Inserting batch 4949000 to 4950000
# → Inserting batch 4950000 to 4951000
# → Inserting batch 4951000 to 4952000
# → Inserting batch 4952000 to 4953000
# → Inserting batch 4953000 to 4954000
# → Inserting batch 4954000 to 4955000
# → Inserting batch 4955000 to 4956000
# → Inserting batch 4956000 to 4957000
# → Inserting batch 4957000 to 4958000
# → Inserting batch 4958000 to 4959000
# → Inserting batch 4959000 to 4960000
# → Inserting batch 4960000 to 4961000
# → Inserting batch 4961000 to 4962000
# → Inserting batch 4962000 to 4963000
# → Inserting batch 4963000 to 4964000
# → Inserting batch 4964000 to 4965000
# → Inserting batch 4965000 to 4966000
# → Inserting batch 4966000 to 4967000
# → Inserting batch 4967000 to 4968000
# → Inserting batch 4968000 to 4969000
# → Inserting batch 4969000 to 4970000
# → Inserting batch 4970000 to 4971000
# → Inserting batch 4971000 to 4972000
# → Inserting batch 4972000 to 4973000
# → Inserting batch 4973000 to 4974000
# → Inserting batch 4974000 to 4975000
# → Inserting batch 4975000 to 4976000
# → Inserting batch 4976000 to 4977000
# → Inserting batch 4977000 to 4978000
# → Inserting batch 4978000 to 4979000
# → Inserting batch 4979000 to 4980000
# → Inserting batch 4980000 to 4981000
# → Inserting batch 4981000 to 4982000
# → Inserting batch 4982000 to 4983000
# → Inserting batch 4983000 to 4984000
# → Inserting batch 4984000 to 4985000
# → Inserting batch 4985000 to 4986000
# → Inserting batch 4986000 to 4987000
# → Inserting batch 4987000 to 4988000
# → Inserting batch 4988000 to 4989000
# → Inserting batch 4989000 to 4990000
# → Inserting batch 4990000 to 4991000
# → Inserting batch 4991000 to 4992000
# → Inserting batch 4992000 to 4993000
# → Inserting batch 4993000 to 4994000
# → Inserting batch 4994000 to 4995000
# → Inserting batch 4995000 to 4996000
# → Inserting batch 4996000 to 4997000
# → Inserting batch 4997000 to 4998000
# → Inserting batch 4998000 to 4999000
# → Inserting batch 4999000 to 5000000
# → Inserting batch 5000000 to 5001000
# → Inserting batch 5001000 to 5002000
# → Inserting batch 5002000 to 5003000
# → Inserting batch 5003000 to 5004000
# → Inserting batch 5004000 to 5005000
# → Inserting batch 5005000 to 5006000
# → Inserting batch 5006000 to 5007000
# → Inserting batch 5007000 to 5008000
# → Inserting batch 5008000 to 5009000
# → Inserting batch 5009000 to 5010000
# → Inserting batch 5010000 to 5011000
# → Inserting batch 5011000 to 5012000
# → Inserting batch 5012000 to 5013000
# → Inserting batch 5013000 to 5014000
# → Inserting batch 5014000 to 5015000
# → Inserting batch 5015000 to 5016000
# → Inserting batch 5016000 to 5017000
# → Inserting batch 5017000 to 5018000
# → Inserting batch 5018000 to 5019000
# → Inserting batch 5019000 to 5020000
# → Inserting batch 5020000 to 5021000
# → Inserting batch 5021000 to 5022000
# → Inserting batch 5022000 to 5023000
# → Inserting batch 5023000 to 5024000
# → Inserting batch 5024000 to 5025000
# → Inserting batch 5025000 to 5026000
# → Inserting batch 5026000 to 5027000
# → Inserting batch 5027000 to 5028000
# → Inserting batch 5028000 to 5029000
# → Inserting batch 5029000 to 5030000
# → Inserting batch 5030000 to 5031000
# → Inserting batch 5031000 to 5032000
# → Inserting batch 5032000 to 5033000
# → Inserting batch 5033000 to 5034000
# → Inserting batch 5034000 to 5035000
# → Inserting batch 5035000 to 5036000
# → Inserting batch 5036000 to 5037000
# → Inserting batch 5037000 to 5038000
# → Inserting batch 5038000 to 5039000
# → Inserting batch 5039000 to 5040000
# → Inserting batch 5040000 to 5041000
# → Inserting batch 5041000 to 5042000
# → Inserting batch 5042000 to 5043000
# → Inserting batch 5043000 to 5044000
# → Inserting batch 5044000 to 5045000
# → Inserting batch 5045000 to 5046000
# → Inserting batch 5046000 to 5047000
# → Inserting batch 5047000 to 5048000
# → Inserting batch 5048000 to 5049000
# → Inserting batch 5049000 to 5050000
# → Inserting batch 5050000 to 5051000
# → Inserting batch 5051000 to 5052000
# → Inserting batch 5052000 to 5053000
# → Inserting batch 5053000 to 5054000
# → Inserting batch 5054000 to 5055000
# → Inserting batch 5055000 to 5056000
# → Inserting batch 5056000 to 5057000
# → Inserting batch 5057000 to 5058000
# → Inserting batch 5058000 to 5059000
# → Inserting batch 5059000 to 5060000
# → Inserting batch 5060000 to 5061000
# → Inserting batch 5061000 to 5062000
# → Inserting batch 5062000 to 5063000
# → Inserting batch 5063000 to 5064000
# → Inserting batch 5064000 to 5065000
# → Inserting batch 5065000 to 5066000
# → Inserting batch 5066000 to 5067000
# → Inserting batch 5067000 to 5068000
# → Inserting batch 5068000 to 5069000
# → Inserting batch 5069000 to 5070000
# → Inserting batch 5070000 to 5071000
# → Inserting batch 5071000 to 5072000
# → Inserting batch 5072000 to 5073000
# → Inserting batch 5073000 to 5074000
# → Inserting batch 5074000 to 5075000
# → Inserting batch 5075000 to 5076000
# → Inserting batch 5076000 to 5077000
# → Inserting batch 5077000 to 5078000
# → Inserting batch 5078000 to 5079000
# ✅ transactions inserted
# STEP 12: Commit...
# ✅ Database created successfully in 961.49s

# %% [markdown]
# ### 2.1. Understand the Schema
#
# The database has two core tables and one convenience view:
#
# - **`accounts`** — who owns each account (bank, account number, entity name)
# - **`transactions`** — every transfer between accounts (amount, currency, timestamp, payment format)
# - **`account_transactions`** (view) — a flattened, account-centric view of transactions. Each transaction appears **twice**: once as an OUT row for the sender, once as an IN row for the receiver. This makes it easy to query all activity for a single account without a `UNION` every time.
#
# Let's look at the raw DDL:

# %%
print(DDL_PATH.read_text())
# Out:
# DROP VIEW IF EXISTS "account_transactions";
#
# DROP TABLE IF EXISTS "accounts";
# CREATE TABLE "accounts" (
#     "bank_name" TEXT,
#     "bank_id" INTEGER,
#     "account_number" TEXT,
#     "entity_id" TEXT,
#     "entity_name" TEXT,
#     PRIMARY KEY ("bank_id", "account_number")
# );
#
# DROP TABLE IF EXISTS "transactions";
# CREATE TABLE "transactions" (
#     "transaction_id" TEXT PRIMARY KEY,
#     "timestamp" Text,
#     "date" TEXT,
#     "day_of_week" TEXT,
#     "time_of_day" TEXT,
#     "from_bank" INTEGER,
#     "from_account" TEXT,
#     "to_bank" INTEGER,
#     "to_account" TEXT,
#     "amount_received" REAL,
#     "receiving_currency" TEXT,
#     "amount_paid" REAL,
#     "payment_currency" TEXT,
#     "payment_format" TEXT,
#     FOREIGN KEY ("from_bank", "from_account")
#         REFERENCES "accounts" ("bank_id", "account_number"),
#     FOREIGN KEY ("to_bank", "to_account")
#         REFERENCES "accounts" ("bank_id", "account_number")
# );
#
# CREATE VIEW account_transactions AS
# SELECT
#   transaction_id,
#   timestamp,
#   from_account AS account,
#   'OUT' AS direction,
#   to_account AS counterparty,
#   from_bank AS bank,
#   to_bank AS counterparty_bank,
#   amount_paid AS amount,
#   payment_currency AS currency,
#   payment_format
# FROM transactions
# UNION ALL
# SELECT
#   transaction_id,
#   timestamp,
#   to_account AS account,
#   'IN' AS direction,
#   from_account AS counterparty,
#   to_bank AS bank,
#   from_bank AS counterparty_bank,
#   amount_received AS amount,
#   receiving_currency AS currency,
#   payment_format
# FROM transactions;

# %% [markdown]
# ## 3. Manual Exploration with `pandas` + `sqlite3`
#
# Let's get familiar with the data before involving any agent.

# %%
conn = sqlite3.connect(DB_PATH)

# Quick sanity check: how many rows in each table?
for table in ["accounts", "transactions"]:
    count = pd.read_sql(f"SELECT COUNT(*) AS n FROM {table}", conn).iloc[0]["n"]
    print(f"{table:20s}: {count:,} rows")
# Out:
# accounts            : 518,581 rows
# transactions        : 5,078,336 rows

# %%
# Preview the accounts table
pd.read_sql("SELECT * FROM accounts LIMIT 10", conn)
# Out:
#                      bank_name  bank_id account_number  entity_id  \
# 0          Portugal Bank #4507   331579      80B779D80  80062E240
# 1              Canada Bank #27      210      809D86900  800C998A0
# 2                  UK Bank #33    21884      80812BE00  800C47F50
# 3           Germany Bank #4815    32742      81047F300  80096F0B0
# 4  National Bank of Harrisburg   127390      80BD8CF00  800FB8760
# 5              Spain Bank #439   224555      80F269580  80064EB20
# 6        Savings Bank of Omaha    32013      80E6E8680  800CCEDE0
# 7              Brazil Bank #39   335355      80CDEFD80  800D88F10
# 8              Mexico Bank #16     1132      80B723600  800D3F760
# 9              Russia Bank #39   217824      806B17000  800B44480
#
#                   entity_name
# 0  Sole Proprietorship #50438
# 1          Corporation #33520
# 2          Partnership #35397
# 3          Corporation #48813
# 4            Corporation #889
# 5  Sole Proprietorship #42987
# 6  Sole Proprietorship #20855
# 7          Partnership #36822
# 8          Partnership #36511
# 9          Partnership #33830

# %%
# Preview the transactions table
pd.read_sql("SELECT * FROM transactions LIMIT 10", conn)
# Out:
#      transaction_id            timestamp        date day_of_week time_of_day  \
# 0  7abd6ee7ce337fa6  2022-09-01T00:00:00  2022-09-01    Thursday    00:00:00
# 1  b20fff430d669279  2022-09-01T00:00:00  2022-09-01    Thursday    00:00:00
# 2  cadfa0752d04b411  2022-09-01T00:00:00  2022-09-01    Thursday    00:00:00
# 3  52686389365c1dbb  2022-09-01T00:00:00  2022-09-01    Thursday    00:00:00
# 4  bb04ab773bf948f4  2022-09-01T00:00:00  2022-09-01    Thursday    00:00:00
# 5  9cab46e294b23f33  2022-09-01T00:00:00  2022-09-01    Thursday    00:00:00
# 6  56a6d97492dd7e9e  2022-09-01T00:00:00  2022-09-01    Thursday    00:00:00
# 7  09d9ed451d4ed49a  2022-09-01T00:00:00  2022-09-01    Thursday    00:00:00
# 8  b81f975bae134449  2022-09-01T00:00:00  2022-09-01    Thursday    00:00:00
# 9  562f94dd547e0314  2022-09-01T00:00:00  2022-09-01    Thursday    00:00:00
#
#    from_bank from_account  to_bank to_account  amount_received  \
# 0       3209    8000F4670     3209  8000F4670         14675.57
# 1       1420    8005DFEB0     1420  8005DFEB0           897.37
# 2         10    8000F6850       10  8000F6850         99986.94
# 3         12    8001167D0       12  8001167D0            16.08
# 4          1    8001364A0        1  8001364A0            10.30
# 5          1    800139380        1  800139380            18.51
# 6        220    800132390      220  800132390            19.23
# 7          1    8001495E0        1  8001495E0         19227.79
# 8       3292    8001541B0     3292  8001541B0          3776.79
# 9       3211    8001583E0     3211  8001583E0           400.56
#
#   receiving_currency  amount_paid payment_currency payment_format
# 0          US Dollar     14675.57        US Dollar   Reinvestment
# 1          US Dollar       897.37        US Dollar   Reinvestment
# 2          US Dollar     99986.94        US Dollar   Reinvestment
# 3          US Dollar        16.08        US Dollar   Reinvestment
# 4          US Dollar        10.30        US Dollar   Reinvestment
# 5          US Dollar        18.51        US Dollar   Reinvestment
# 6          US Dollar        19.23        US Dollar   Reinvestment
# 7          US Dollar     19227.79        US Dollar   Reinvestment
# 8          US Dollar      3776.79        US Dollar   Reinvestment
# 9          US Dollar       400.56        US Dollar   Reinvestment

# %%
# Preview the account_transactions view
# Notice each transaction appears as both an IN row and an OUT row
sample_tx = pd.read_sql("SELECT transaction_id FROM transactions LIMIT 1", conn).iloc[0]["transaction_id"]

print(f"Looking up transaction: {sample_tx}\n")
pd.read_sql(f"SELECT * FROM account_transactions WHERE transaction_id = '{sample_tx}'", conn)
# Out:
# Looking up transaction: 000002908b4740a1
#      transaction_id            timestamp    account direction counterparty  \
# 0  000002908b4740a1  2022-09-02T23:43:00  803A621E0       OUT    803F400C0
# 1  000002908b4740a1  2022-09-02T23:43:00  803F400C0        IN    803A621E0
#
#     bank  counterparty_bank     amount currency payment_format
# 0     21              10099  290618.32      Yen         Cheque
# 1  10099                 21  290618.32      Yen         Cheque

# %%
conn.close()

# %% [markdown]
# ## 4. The `ReadOnlySqlDatabase` Tool
#
# So far we've been using `sqlite3` directly — a regular connection that could run `DROP TABLE` or `DELETE` if we wanted.
#
# When an LLM agent runs SQL, we can't have it modifying data. The [`ReadOnlySqlDatabase`](https://github.com/VectorInstitute/eval-agents/blob/main/aieng-eval-agents/aieng/agent_evals/tools/sql_database.py) tool solves this with two layers of protection:
#
# 1. **AST-level enforcement** — It parses the SQL into a syntax tree using [SQLGlot](https://sqlglot.com/) and rejects any query that contains write operations (`INSERT`, `UPDATE`, `DROP`, etc.), even if hidden inside a CTE or subquery.
# 2. **Row limits + timeouts** — It caps results at `max_rows` (default 100) and cancels slow queries, preventing runaway costs.
#
# The tool exposes exactly **two methods** that become the agent's "tools":
# - `get_schema_info()` — returns the table/column names
# - `execute(query)` — runs a SELECT and returns a markdown table string

# %%
db = ReadOnlySqlDatabase(
    connection_uri=f"sqlite:///{DB_PATH}",
    agent_name="NotebookExplorer",
    max_rows=10,  # keep output short for this notebook
)

print("Tool created successfully!")
print(f"Max rows: {db.max_rows}")
print(f"Agent name: {db.agent_name}")
# Out:
# Tool created successfully!
# Max rows: 10
# Agent name: NotebookExplorer

# %% [markdown]
# ### 4.1. Schema Discovery
#
# This is the first thing the agent does on every case — ask "what tables exist and what columns do they have?"

# %%
schema = db.get_schema_info()
print(schema)
# Out:
# Table: accounts
#   Columns: bank_name: TEXT, bank_id: INTEGER, account_number: TEXT, entity_id: TEXT, entity_name: TEXT
# Table: transactions
#   Columns: transaction_id: TEXT, timestamp: TEXT, date: TEXT, day_of_week: TEXT, time_of_day: TEXT, from_bank: INTEGER, from_account: TEXT, to_bank: INTEGER, to_account: TEXT, amount_received: REAL, receiving_currency: TEXT, amount_paid: REAL, payment_currency: TEXT, payment_format: TEXT
# View: account_transactions
#   Columns: transaction_id: TEXT, timestamp: TEXT, account: TEXT, direction: NULL, counterparty: TEXT, bank: INTEGER, counterparty_bank: INTEGER, amount: REAL, currency: TEXT, payment_format: TEXT

# %%
# You can also ask for a specific table only
print(db.get_schema_info(table_names=["transactions"]))
# Out:
# Table: transactions
#   Columns: transaction_id: TEXT, timestamp: TEXT, date: TEXT, day_of_week: TEXT, time_of_day: TEXT, from_bank: INTEGER, from_account: TEXT, to_bank: INTEGER, to_account: TEXT, amount_received: REAL, receiving_currency: TEXT, amount_paid: REAL, payment_currency: TEXT, payment_format: TEXT

# %% [markdown]
# ### 4.2. Running Queries Through the Tool
#
# Notice that the output is a **markdown table string** — not a DataFrame. This is intentional: the agent receives it as plain text in its context window.

# %%
result = db.execute("SELECT * FROM accounts LIMIT 5")
print(result)
# Out:
# | bank_name | bank_id | account_number | entity_id | entity_name |
# | --- | --- | --- | --- | --- |
# | Portugal Bank #4507 | 331579 | 80B779D80 | 80062E240 | Sole Proprietorship #50438 |
# | Canada Bank #27 | 210 | 809D86900 | 800C998A0 | Corporation #33520 |
# | UK Bank #33 | 21884 | 80812BE00 | 800C47F50 | Partnership #35397 |
# | Germany Bank #4815 | 32742 | 81047F300 | 80096F0B0 | Corporation #48813 |
# | National Bank of Harrisburg | 127390 | 80BD8CF00 | 800FB8760 | Corporation #889 |

# %%
# Aggregation query. This is the kind of query the agent would run
result = db.execute("""
    SELECT
        account,
        COUNT(*) AS tx_count,
        COUNT(DISTINCT counterparty) AS unique_counterparties,
        SUM(CASE WHEN direction='IN' THEN amount ELSE 0 END) AS total_in,
        SUM(CASE WHEN direction='OUT' THEN amount ELSE 0 END) AS total_out
    FROM account_transactions
    GROUP BY account
    ORDER BY tx_count DESC
    LIMIT 10
""")
print(result)
# Out:
# | account | tx_count | unique_counterparties | total_in | total_out |
# | --- | --- | --- | --- | --- |
# | 100428660 | 169756 | 14775 | 479594.79 | 52762291209.75 |
# | 1004286A8 | 103671 | 9174 | 251001.27 | 26069375477.37 |
# | 100428978 | 20647 | 1851 | 44445.62 | 7532109611.71 |
# | 1004286F0 | 18771 | 1630 | 253933.88 | 24657357382.93 |
# | 100428780 | 17381 | 1482 | 10570889.95 | 373933699163.91003 |
# | 1004289C0 | 16926 | 1500 | 313581.33 | 10517190140.53 |
# | 100428810 | 16540 | 1452 | 27366.88 | 5153615843.1 |
# | 1004287C8 | 14277 | 1236 | 5474418.39 | 101107241619.05 |
# | 100428738 | 13854 | 1187 | 6304388.45 | 259216781715.29 |
# | 100428A51 | 13101 | 1161 | 0.52359 | 262859.640408 |
#
# ... (Truncated at 10 rows) ...

# %% [markdown]
# ### 4.3. Safety Demo — Write Operations Are Blocked
#
# Let's verify the protection actually works. The tool should reject any write operation.

# %%
# Attempting a DELETE. This should be blocked
result = db.execute("DELETE FROM transactions WHERE 1=1")
print(result)  # Expect: "Query Error: Security Violation..."
# Out:
# 2026-03-19 18:50:45,228 WARNING aieng.agent_evals.tools.sql_database: Blocked Unsafe Query Type: <class 'sqlglot.expressions.Delete'>
# Query Error: Security Violation: Query contains prohibited WRITE operations.

# %%
# Attempting a write hidden inside a CTE — also blocked
result = db.execute("""
    WITH cleanup AS (
        DELETE FROM transactions WHERE 1=1
    )
    SELECT * FROM accounts LIMIT 1
""")
print(result)  # Expect: "Query Error: Security Violation..."
# Out:
# 2026-03-19 18:50:51,871 WARNING aieng.agent_evals.tools.sql_database: CTE usage blocked by policy
# Query Error: Security Violation: Query contains prohibited WRITE operations.

# %%
# Row limit enforcement — we set max_rows=10 above, so this won't return all rows
result = db.execute("SELECT * FROM transactions")
# Check the last line — it should say "Truncated at 10 rows"
for line in result.split("\n")[-3:]:
    print(line)
# Out:
# | 562f94dd547e0314 | 2022-09-01T00:00:00 | 2022-09-01 | Thursday | 00:00:00 | 3211 | 8001583E0 | 3211 | 8001583E0 | 400.56 | US Dollar | 400.56 | US Dollar | Reinvestment |
#
# ... (Truncated at 10 rows) ...

# %% [markdown]
# ## Summary
#
# In this notebook you've seen:
#
# 1. **The dataset** — the IBM Transactions for Anti Money Laundering (AML) dataset, its structure, and how to download and clean it.
# 2. **The database** — two tables (`accounts`, `transactions`) and a convenience view (`account_transactions`) storing synthetic AML transaction data.
# 3. **Manual exploration** — how to use `pandas` + `sqlite3` to query the data as a developer would.
# 4. **The `ReadOnlySqlDatabase` tool** — the safety-hardened wrapper the agent uses, with AST-level write blocking and row limits.
#
# **Next:** In Notebook 2, we'll instantiate the AML agent, explore how to give it tasks, then inspect its reasoning and tool call trace.

# %%
db.close()
print("Done!")
# Out:
# Done!
